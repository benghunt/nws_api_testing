# %%
import requests, json
import re
from datetime import datetime

# %%
apistarturl = 'https://api.weather.gov'

def get_location_url_from_coords(lat,lon):
    return apistarturl + '/points/' + str(lat) + ',' + str(lon)


#HERE IS WHERE YOU CHANGE THE LAT / LON OF THE AREA YOU ARE INTERESTED IN

url = get_location_url_from_coords(29.9511,-90.0715)

#NEW ORLEANS IS USED AS THE DEFAULT 29.9511,-90.0715

print(url)
# Out:
# https://api.weather.gov/points/33.7513419,-117.9939921

# %%
r = requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
location_json_obj = json.loads(r.text)
print(location_json_obj.keys())
print(location_json_obj['properties'].keys())
# Out:
# dict_keys(['@context', 'id', 'type', 'geometry', 'properties'])
# dict_keys(['@id', '@type', 'cwa', 'forecastOffice', 'gridId', 'gridX', 'gridY', 'forecast', 'forecastHourly', 'forecastGridData', 'observationStations', 'relativeLocation', 'forecastZone', 'county', 'fireWeatherZone', 'timeZone', 'radarStation'])

# %%
office = location_json_obj['properties']['gridId']
station = 'K'+ office
print(office)
print(station)
products_in_station_url = apistarturl + '/products/locations/' + office + '/types'
print(products_in_station_url)
r = requests.get(products_in_station_url)
print(r)
# Out:
# SGX
# KSGX
# https://api.weather.gov/products/locations/SGX/types
# <Response [200]>

# %%
products_at_station = json.loads(r.text)['@graph']
products_at_station
# Out:
# [{'productCode': 'AFD', 'productName': 'Area Forecast Discussion'},
#  {'productCode': 'CFW',
#   'productName': 'Coastal Flood Warnings/Watches/Statements'},
#  {'productCode': 'CGR', 'productName': 'Coast Guard Surface Report'},
#  {'productCode': 'CWF', 'productName': 'Coastal Waters Forecast'},
#  {'productCode': 'ESF', 'productName': 'Flood Potential Outlook'},
#  {'productCode': 'FDI', 'productName': 'Fire Danger Indices'},
#  {'productCode': 'FLS', 'productName': 'Flood Statement'},
#  {'productCode': 'FWF',
#   'productName': 'Routine Fire Wx Fcst (With/Without 6-10 Day Outlook)'},
#  {'productCode': 'FWL', 'productName': 'Land Management Forecasts'},
#  {'productCode': 'FWM', 'productName': 'Miscellaneous Fire Weather Product'},
#  {'productCode': 'FWN', 'productName': 'Fire Weather Notification'},
#  {'productCode': 'FWO', 'productName': 'Fire Weather Observation'},
#  {'productCode': 'FWS', 'productName': 'Suppression Forecast'},
#  {'productCode': 'HML', 'productName': 'AHPS XML'},
#  {'productCode': 'LSR', 'productName': 'Local Storm Report'},
#  {'productCode': 'MWS', 'productName': 'Marine Weather Statement'},
#  {'productCode': 'NPW',
#   'productName': 'Non-Precipitation Warnings / Watches / Advisories'},
#  {'productCode': 'PFM', 'productName': 'Point Forecast Matrices'},
#  {'productCode': 'RER', 'productName': 'Record Report'},
#  {'productCode': 'RR2', 'productName': 'Hydro-Met Data Report Part 2'},
#  {'productCode': 'RR3', 'productName': 'Hydro-Met Data Report Part 3'},
#  {'productCode': 'RRS', 'productName': 'HADS Data'},
#  {'productCode': 'RTP',
#   'productName': 'Regional Max/Min Temp and Precipitation Table'},
#  {'productCode': 'RWR', 'productName': 'Regional Weather Roundup'},
#  {'productCode': 'SFT', 'productName': 'Tabular State Forecast'},
#  {'productCode': 'SPS', 'productName': 'Special Weather Statement'},
#  {'productCode': 'SRF', 'productName': 'Surf Forecast'},
#  {'productCode': 'STQ', 'productName': 'Spot Forecast Request'},
#  {'productCode': 'VFT',
#   'productName': 'Terminal Aerodrome Forecast (TAF) Verification'},
#  {'productCode': 'ZFP', 'productName': 'Zone Forecast Product'}]

# %%
#THIS IS AN IMPORTANT LINE
#v v v v vv v v v v v v v  
desired_product_code = 'PFM'
# ^ ^ ^ ^ ^ ^ ^ ^ ^ ^ ^ ^
#HERE IS WHERE YOU CHANGE THE PRODUCT CODE TO BE THE THREE LETTER PRODUCT OF INTEREST

for product in products_at_station:
    if product['productCode'] == desired_product_code:
        print(product)
recentProductURL = apistarturl + '/products/types/' + desired_product_code
print(recentProductURL)
r = requests.get(recentProductURL)
print(r)
# Out:
# {'productCode': 'PFM', 'productName': 'Point Forecast Matrices'}
# https://api.weather.gov/products/types/PFM
# <Response [200]>

# %%
recentProductURL = apistarturl + '/products/types/' + desired_product_code
recentProductURL
# Out:
# 'https://api.weather.gov/products/types/PFM'

# %%
recentProductsJSON = json.loads(r.text)
print(recentProductsJSON.keys())
station_products = []
for product in recentProductsJSON['@graph']:
    if product['issuingOffice'] == station:
        station_products.append(product)
station_products[0]
# Out:
# dict_keys(['@context', '@graph'])
# {'@id': 'https://api.weather.gov/products/4b8627cb-3492-414d-872a-c11aa4f6e924',
#  'id': '4b8627cb-3492-414d-872a-c11aa4f6e924',
#  'wmoCollectiveId': 'FOUS56',
#  'issuingOffice': 'KSGX',
#  'issuanceTime': '2022-07-21T09:11:00+00:00',
#  'productCode': 'PFM',
#  'productName': 'Point Forecast Matrices'}

# %%
#HERE IS WHERE THE PRODUCTS AVAILABLE ARE REDUCED TO THE MOST RECENT ONE

t1 = datetime.strptime(station_products[0]['issuanceTime'].split('+')[0], '%Y-%m-%dT%H:%M:%S')
t2 = datetime.strptime(station_products[1]['issuanceTime'].split('+')[0], '%Y-%m-%dT%H:%M:%S')
most_recent_date = datetime(1,1,1)
most_recent_product = ''
for product in station_products:
    product_date = datetime.strptime(product['issuanceTime'].split('+')[0], '%Y-%m-%dT%H:%M:%S')
    if most_recent_date < product_date:
        most_recent_product = product
        most_recent_date = product_date

# %%
most_recent_product
# Out:
# {'@id': 'https://api.weather.gov/products/4b8627cb-3492-414d-872a-c11aa4f6e924',
#  'id': '4b8627cb-3492-414d-872a-c11aa4f6e924',
#  'wmoCollectiveId': 'FOUS56',
#  'issuingOffice': 'KSGX',
#  'issuanceTime': '2022-07-21T09:11:00+00:00',
#  'productCode': 'PFM',
#  'productName': 'Point Forecast Matrices'}

# %%
most_recent_product_url = most_recent_product['@id']

# %%
r =requests.get(most_recent_product_url)
print(r)
product_json = json.loads(r.text)
print(product_json.keys())
# Out:
# <Response [200]>
# dict_keys(['@context', '@id', 'id', 'wmoCollectiveId', 'issuingOffice', 'issuanceTime', 'productCode', 'productName', 'productText'])

# %%
print(product_json['productText'])
# Out:
# 000
# FOUS56 KSGX 210911
# PFMSGX
#
# Point Forecast Matrices
# National Weather Service San Diego CA
# 211 AM PDT Thu Jul 21 2022
#
# CAZ552-220000-
# John Wayne Airport-Orange CA
# 33.68N 117.87W ELEV. 52 FT
# 211 AM PDT Thu Jul 21 2022
#
# DATE                Thu 07/21/22            Fri 07/22/22            Sat 07/23/22
# PDT 3HRLY     02 05 08 11 14 17 20 23 02 05 08 11 14 17 20 23 02 05 08 11 14 17
# UTC 3HRLY     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# MAX/MIN                      79          65          78          64          79
# TEMP             66 69 76 78 76 69 66 65 65 68 75 77 76 69 67 66 65 68 75 77 76
# DEWPT            62 63 63 62 63 63 62 62 62 63 64 64 63 63 63 62 62 63 65 64 63
# RH               87 81 64 58 64 81 87 90 90 84 69 64 64 81 87 87 90 84 71 64 64
# WIND DIR          S  S SW SW SW SW  S  S SE  S SW SW SW SW  S SE SE  S SW SW SW
# WIND SPD          2  2  8  9  8  6  4  3  3  3  9 10  9  6  4  3  3  3  8  9  9
# CLOUDS           SC B1 FW FW FW FW B1 B1 B2 B1 FW FW FW FW B1 B1 B1 B1 FW FW FW
# POP 12HR                      0           0           0           0           0
# QPF 12HR                      0           0           0           0           0
# OBVIS            PF PF             PF PF PF PF             PF PF PF PF
#
#
# DATE               Sun 07/24/22  Mon 07/25/22  Tue 07/26/22  Wed 07/27/22
# PDT 6HRLY     23   05 11 17 23   05 11 17 23   05 11 17 23   05 11 17
# UTC 6HRLY     06   12 18 00 06   12 18 00 06   12 18 00 06   12 18 00
#
# MIN/MAX            64    77      64    77      64    76      65    77
# TEMP          66   65 74 75 66   65 73 73 66   66 73 73 66   66 74 74
# DEWPT         63   62 64 62 62   61 64 62 62   61 64 61 62   61 64 62
# PWIND DIR          SW     S       S    SW       S    SW      SW    SW
# WIND CHAR          LT    LT      LT    LT      LT    LT      LT    LT
# AVG CLOUDS    FW   SC SC FW FW   B1 B1 FW SC   SC SC SC SC   B1 B1 SC
# POP 12HR            0     0       5     5       5     5       5     5
#
# $$
# CAZ554-220000-
# Fullerton-Orange CA
# 33.87N 117.98W ELEV. 95 FT
# 211 AM PDT Thu Jul 21 2022
#
# DATE                Thu 07/21/22            Fri 07/22/22            Sat 07/23/22
# PDT 3HRLY     02 05 08 11 14 17 20 23 02 05 08 11 14 17 20 23 02 05 08 11 14 17
# UTC 3HRLY     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# MAX/MIN                      84          65          83          65          83
# TEMP             66 69 78 82 81 73 69 67 66 68 77 81 80 73 68 67 66 68 77 81 81
# DEWPT            61 63 63 61 62 61 62 62 62 63 64 63 63 62 62 62 62 63 64 64 62
# RH               84 81 60 49 53 66 78 84 87 84 64 54 56 68 81 84 87 84 64 56 53
# WIND DIR          S  S SW SW SW  S  S  S SE  S  S SW SW  S  S  S SE SE SW SW SW
# WIND SPD          2  3  5  8  9  8  4  4  4  4  5  8  9  8  4  4  4  3  5  8  8
# CLOUDS           SC SC FW FW FW FW SC SC B1 B1 FW FW FW FW SC SC SC SC FW FW FW
# POP 12HR                      0           0           0           0           0
# QPF 12HR                      0           0           0           0           0
# OBVIS            PF PF             PF PF PF PF             PF PF PF PF
#
#
# DATE               Sun 07/24/22  Mon 07/25/22  Tue 07/26/22  Wed 07/27/22
# PDT 6HRLY     23   05 11 17 23   05 11 17 23   05 11 17 23   05 11 17
# UTC 6HRLY     06   12 18 00 06   12 18 00 06   12 18 00 06   12 18 00
#
# MIN/MAX            66    82      65    80      65    80      65    80
# TEMP          68   67 76 80 67   65 75 77 67   66 75 78 67   66 75 78
# DEWPT         62   62 63 62 61   60 63 62 61   60 63 61 61   60 63 61
# PWIND DIR           S     S       S     S       S    SW      SW    SW
# WIND CHAR          LT    LT      LT    LT      LT    LT      LT    LT
# AVG CLOUDS    FW   SC SC FW FW   SC SC FW FW   SC SC SC SC   SC SC FW
# POP 12HR            0     5       5     5       0     5       5     5
#
# $$
# CAZ048-220000-
# Ontario-San Bernardino CA
# 34.05N 117.58W ELEV. 942 FT
# 211 AM PDT Thu Jul 21 2022
#
# DATE                Thu 07/21/22            Fri 07/22/22            Sat 07/23/22
# PDT 3HRLY     02 05 08 11 14 17 20 23 02 05 08 11 14 17 20 23 02 05 08 11 14 17
# UTC 3HRLY     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# MAX/MIN                      93          67          93          67          93
# TEMP             69 74 85 92 90 82 74 70 67 71 83 91 90 81 74 70 68 71 83 92 91
# DEWPT            56 58 55 56 56 57 59 59 59 61 60 58 58 59 60 60 60 61 61 59 58
# RH               63 57 36 30 32 43 59 68 75 71 46 33 34 47 62 71 76 71 47 33 33
# WIND DIR          W SW SW  W  W  W  W  W  W SW SW  W  W  W  W  W SW SW SW  W  W
# WIND SPD          1  2  5 11 13 10  6  5  3  1  5 12 14 11  6  5  2  1  5 12 14
# CLOUDS           FW FW FW FW FW FW FW FW FW FW FW FW FW FW FW FW FW FW FW FW FW
# POP 12HR                      0           0           0           0           0
# QPF 12HR                      0           0           0           0           0
#
#
# DATE               Sun 07/24/22  Mon 07/25/22  Tue 07/26/22  Wed 07/27/22
# PDT 6HRLY     23   05 11 17 23   05 11 17 23   05 11 17 23   05 11 17
# UTC 6HRLY     06   12 18 00 06   12 18 00 06   12 18 00 06   12 18 00
#
# MIN/MAX            67    93      65    90      67    89      66    89
# TEMP          74   68 83 89 72   66 81 87 72   68 80 86 72   67 80 86
# DEWPT         60   61 61 57 60   59 62 59 60   59 62 58 60   59 62 57
# PWIND DIR           W     W       W     W       W    SW       W    SW
# WIND CHAR          LT    LT      GN    LT      GN    LT      GN    LT
# AVG CLOUDS    FW   FW FW FW FW   FW FW SC SC   SC FW SC SC   SC SC SC
# POP 12HR            0     5       5    10       5    10       5     5
#
# $$
# CAZ048-220000-
# Riverside-Riverside CA
# 33.95N 117.45W ELEV. 817 FT
# 211 AM PDT Thu Jul 21 2022
#
# DATE                Thu 07/21/22            Fri 07/22/22            Sat 07/23/22
# PDT 3HRLY     02 05 08 11 14 17 20 23 02 05 08 11 14 17 20 23 02 05 08 11 14 17
# UTC 3HRLY     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# MAX/MIN                      95          67          96          67          96
# TEMP             70 73 85 94 92 82 74 70 68 72 84 94 92 82 74 71 68 71 84 94 92
# DEWPT            55 56 53 54 53 56 58 58 59 60 58 57 56 57 59 60 60 60 59 57 56
# RH               59 55 33 26 27 41 57 66 73 66 41 29 30 43 59 68 76 68 43 29 30
# WIND DIR         NW  W  W  W  W  W  W  W NW NW  W  W  W  W  W  W NW  W  W  W  W
# WIND SPD          1  2  4 11 13 10  5  3  2  1  4 11 14 10  3  3  1  1  4 11 13
# CLOUDS           FW FW FW FW FW FW FW FW FW FW FW FW FW FW FW FW SC SC FW FW FW
# POP 12HR                      0           0           0           0           0
# QPF 12HR                      0           0           0           0           0
#
#
# DATE               Sun 07/24/22  Mon 07/25/22  Tue 07/26/22  Wed 07/27/22
# PDT 6HRLY     23   05 11 17 23   05 11 17 23   05 11 17 23   05 11 17
# UTC 6HRLY     06   12 18 00 06   12 18 00 06   12 18 00 06   12 18 00
#
# MIN/MAX            67    95      66    93      67    92      66    92
# TEMP          74   68 83 91 73   68 81 88 72   68 81 88 72   68 81 88
# DEWPT         60   60 60 56 59   59 61 58 60   59 61 56 60   59 61 55
# PWIND DIR           W     W       W     W       W     W       W     W
# WIND CHAR          LT    LT      LT    LT      GN    LT      LT    LT
# AVG CLOUDS    FW   FW FW FW FW   FW FW SC SC   SC FW SC SC   SC SC SC
# POP 12HR            0     5       5    10       5    10       5     5
#
# $$
# CAZ048-220000-
# March Air Force Base-Riverside CA
# 33.90N 117.25W ELEV. 1539 FT
# 211 AM PDT Thu Jul 21 2022
#
# DATE                Thu 07/21/22            Fri 07/22/22            Sat 07/23/22
# PDT 3HRLY     02 05 08 11 14 17 20 23 02 05 08 11 14 17 20 23 02 05 08 11 14 17
# UTC 3HRLY     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# MAX/MIN                      96          67          97          67          97
# TEMP             69 76 89 95 94 83 75 70 68 75 89 95 94 83 75 71 68 75 89 95 94
# DEWPT            51 52 49 50 49 51 54 54 54 56 53 52 51 53 56 55 56 57 54 52 53
# RH               53 43 25 22 22 33 48 57 61 52 29 23 23 36 52 57 65 54 30 23 25
# WIND DIR         NW  S  W  W NW NW  W  W SE SE  W  W  W NW  W  S SE SE  W  W  W
# WIND SPD          1  1  4 11 12  9  3  1  1  2  3 10 13 10  2  1  2  1  3 11 12
# CLOUDS           FW FW FW FW FW FW FW FW FW FW FW FW FW FW FW FW SC SC FW FW FW
# POP 12HR                      0           0           0           0           0
# QPF 12HR                      0           0           0           0           0
#
#
# DATE               Sun 07/24/22  Mon 07/25/22  Tue 07/26/22  Wed 07/27/22
# PDT 6HRLY     23   05 11 17 23   05 11 17 23   05 11 17 23   05 11 17
# UTC 6HRLY     06   12 18 00 06   12 18 00 06   12 18 00 06   12 18 00
#
# MIN/MAX            67    96      66    93      66    92      66    93
# TEMP          75   68 88 92 73   67 85 89 73   68 84 89 72   67 84 89
# DEWPT         56   57 56 55 56   57 58 56 57   57 58 54 57   56 58 53
# PWIND DIR           W    SW       W    NW      NW    NW      NW    NW
# WIND CHAR          LT    LT      LT    LT      LT    LT      LT    LT
# AVG CLOUDS    FW   FW FW FW SC   SC SC SC SC   SC FW SC B1   SC SC SC
# POP 12HR            0    10       5    20       5    10      10     5
# RAIN SHWRS                              S
# TSTMS                                   S
#
# $$
# CAZ043-220000-
# Camp Pendleton-San Diego CA
# 33.31N 117.35W ELEV. 79 FT
# 211 AM PDT Thu Jul 21 2022
#
# DATE                Thu 07/21/22            Fri 07/22/22            Sat 07/23/22
# PDT 3HRLY     02 05 08 11 14 17 20 23 02 05 08 11 14 17 20 23 02 05 08 11 14 17
# UTC 3HRLY     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# MAX/MIN                      80          61          79          61          79
# TEMP             66 69 78 79 76 69 65 65 64 67 76 78 75 68 65 64 65 67 76 78 75
# DEWPT            61 62 62 61 61 62 61 60 61 61 63 62 62 63 62 61 61 62 64 63 62
# RH               84 78 58 54 60 78 87 84 90 81 64 58 64 84 90 90 87 84 66 60 64
# WIND DIR          S SW SW SW SW SW  S  S  E SE SW SW SW SW  S  S  E SE SW SW SW
# WIND SPD          0  2  8 11 10  6  3  2  2  2  8 10  9  5  3  2  2  3  8 10  9
# CLOUDS           SC SC FW FW FW FW B1 B1 B2 B1 FW FW FW FW SC SC SC SC FW FW FW
# POP 12HR                      0           0           0           0           0
# QPF 12HR                      0           0           0           0           0
# OBVIS            PF PF             PF PF PF PF             PF PF PF PF
#
#
# DATE               Sun 07/24/22  Mon 07/25/22  Tue 07/26/22  Wed 07/27/22
# PDT 6HRLY     23   05 11 17 23   05 11 17 23   05 11 17 23   05 11 17
# UTC 6HRLY     06   12 18 00 06   12 18 00 06   12 18 00 06   12 18 00
#
# MIN/MAX            62    78      62    77      63    77      62    78
# TEMP          65   65 74 73 65   65 74 72 65   65 75 73 65   65 75 74
# DEWPT         62   62 64 62 61   61 64 62 61   60 64 62 61   61 64 62
# PWIND DIR          SW     S      SW    SW      SW    SW      SW    SW
# WIND CHAR          LT    LT      LT    LT      LT    LT      LT    LT
# AVG CLOUDS    FW   B1 B1 FW SC   B1 B1 B1 SC   B1 B1 SC SC   B1 B1 B1
# POP 12HR            0     5       5    10       5    10       5     5
#
# $$
# CAZ043-220000-
# Carlsbad-San Diego CA
# 33.13N 117.28W ELEV. 328 FT
# 211 AM PDT Thu Jul 21 2022
#
# DATE                Thu 07/21/22            Fri 07/22/22            Sat 07/23/22
# PDT 3HRLY     02 05 08 11 14 17 20 23 02 05 08 11 14 17 20 23 02 05 08 11 14 17
# UTC 3HRLY     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# MAX/MIN                      76          64          75          64          75
# TEMP             66 67 75 75 74 68 66 65 64 66 73 74 73 68 66 65 64 66 72 74 73
# DEWPT            62 63 64 63 63 62 62 62 63 63 65 64 64 63 63 63 63 63 65 65 63
# RH               87 87 69 66 69 81 87 90 97 90 76 71 73 84 90 93 97 90 79 74 71
# WIND DIR         NW  W  W  W SW SW SW  S SE  S SW SW SW SW  S  S SE  S SW SW SW
# WIND SPD          0  2  8  9  8  6  3  2  3  3  9 10  8  5  4  3  4  4  8  9  8
# CLOUDS           SC SC FW FW FW FW B2 B2 B2 B1 FW FW FW FW B1 B1 B1 B1 FW FW FW
# POP 12HR                      0           0           0           0           0
# QPF 12HR                      0           0           0           0           0
# OBVIS            PF PF             PF PF PF PF             PF PF PF PF
#
#
# DATE               Sun 07/24/22  Mon 07/25/22  Tue 07/26/22  Wed 07/27/22
# PDT 6HRLY     23   05 11 17 23   05 11 17 23   05 11 17 23   05 11 17
# UTC 6HRLY     06   12 18 00 06   12 18 00 06   12 18 00 06   12 18 00
#
# MIN/MAX            64    74      64    73      65    74      64    73
# TEMP          65   64 72 71 65   64 71 71 66   66 72 72 65   65 71 71
# DEWPT         62   63 65 62 62   61 65 63 62   61 65 62 62   61 65 63
# PWIND DIR          SW    SW      SW    SW       W     W      SW    SW
# WIND CHAR          LT    LT      LT    LT      LT    LT      LT    LT
# AVG CLOUDS    FW   B1 B1 FW SC   B1 B1 B1 SC   B1 B1 SC SC   B1 B1 B1
# POP 12HR            0    10       5    10       5    10       5     5
#
# $$
# CAZ043-220000-
# Oceanside-San Diego CA
# 33.22N 117.35W ELEV. 30 FT
# 211 AM PDT Thu Jul 21 2022
#
# DATE                Thu 07/21/22            Fri 07/22/22            Sat 07/23/22
# PDT 3HRLY     02 05 08 11 14 17 20 23 02 05 08 11 14 17 20 23 02 05 08 11 14 17
# UTC 3HRLY     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# MAX/MIN                      77          63          76          64          76
# TEMP             65 69 75 76 73 68 66 65 65 68 72 74 72 68 66 66 66 68 72 74 73
# DEWPT            62 62 62 62 62 62 62 61 61 62 63 63 62 62 62 62 62 62 63 63 63
# RH               90 78 64 62 68 81 87 87 87 81 73 69 71 81 87 87 87 81 73 69 71
# WIND DIR         SW SW SW  W SW SW  S  S SE  S SW SW SW SW  S  S SE  S SW SW SW
# WIND SPD          0  2  8  9  8  6  3  3  2  2  8  9  8  5  3  3  4  4  8  9  8
# CLOUDS           B1 B1 FW FW FW SC B2 B2 B2 B2 FW FW FW FW B1 B1 B1 B1 FW FW FW
# POP 12HR                      0           0           0           0           0
# QPF 12HR                      0           0           0           0           0
# OBVIS            PF PF             PF PF PF PF             PF PF PF PF
# HIGH SURF         Y
#
#
# DATE               Sun 07/24/22  Mon 07/25/22  Tue 07/26/22  Wed 07/27/22
# PDT 6HRLY     23   05 11 17 23   05 11 17 23   05 11 17 23   05 11 17
# UTC 6HRLY     06   12 18 00 06   12 18 00 06   12 18 00 06   12 18 00
#
# MIN/MAX            64    74      63    75      64    75      65    75
# TEMP          67   66 72 71 65   66 71 71 66   65 72 72 66   66 73 72
# DEWPT         62   62 63 62 61   61 63 62 61   61 63 62 62   61 63 62
# PWIND DIR          SW    SW      SW    SW       W     W      SW    SW
# WIND CHAR          LT    LT      LT    LT      LT    LT      LT    LT
# AVG CLOUDS    FW   B1 B1 FW SC   B1 B1 B1 SC   B1 B1 SC SC   B2 B2 B1
# POP 12HR            0     5       5    10       5    10       5     5
#
# $$
# CAZ043-220000-
# Miramar-San Diego CA
# 32.87N 117.14W ELEV. 482 FT
# 211 AM PDT Thu Jul 21 2022
#
# DATE                Thu 07/21/22            Fri 07/22/22            Sat 07/23/22
# PDT 3HRLY     02 05 08 11 14 17 20 23 02 05 08 11 14 17 20 23 02 05 08 11 14 17
# UTC 3HRLY     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# MAX/MIN                      81          63          79          63          79
# TEMP             65 69 78 79 76 68 65 65 65 67 76 77 75 68 65 64 64 67 76 77 75
# DEWPT            61 62 60 60 59 60 60 61 60 62 61 61 60 61 61 61 61 62 62 62 60
# RH               87 78 54 52 56 76 84 87 84 84 60 58 60 78 87 90 90 84 62 60 60
# WIND DIR          N  W  W  W  W SW SW SW  S  S SW SW SW SW  S  S  S  S SW SW SW
# WIND SPD          1  2  6  9  6  4  3  2  2  3  8  9  8  5  4  3  3  4  6  8  6
# CLOUDS           FW SC FW FW FW FW B2 OV B2 B1 FW FW FW FW B1 B1 B1 B1 FW FW FW
# POP 12HR                      0           0           0           0           0
# QPF 12HR                      0           0           0           0           0
# OBVIS               PF             PF PF PF PF             PF PF PF PF
#
#
# DATE               Sun 07/24/22  Mon 07/25/22  Tue 07/26/22  Wed 07/27/22
# PDT 6HRLY     23   05 11 17 23   05 11 17 23   05 11 17 23   05 11 17
# UTC 6HRLY     06   12 18 00 06   12 18 00 06   12 18 00 06   12 18 00
#
# MIN/MAX            64    77      63    77      63    78      63    78
# TEMP          65   64 74 73 64   64 74 73 65   64 75 73 64   64 74 73
# DEWPT         61   63 62 61 60   61 62 60 60   60 63 61 61   61 62 60
# PWIND DIR           W     W       W     W       W     W       W     W
# WIND CHAR          LT    LT      LT    LT      LT    LT      LT    LT
# AVG CLOUDS    FW   B1 B1 SC SC   B1 B1 B1 SC   B1 B1 B1 SC   B1 B1 B1
# POP 12HR            0    10       5    10       5    10       5     5
#
# $$
# CAZ043-220000-
# Montgomery Field-San Diego CA
# 32.81N 117.14W ELEV. 407 FT
# 211 AM PDT Thu Jul 21 2022
#
# DATE                Thu 07/21/22            Fri 07/22/22            Sat 07/23/22
# PDT 3HRLY     02 05 08 11 14 17 20 23 02 05 08 11 14 17 20 23 02 05 08 11 14 17
# UTC 3HRLY     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# MAX/MIN                      81          65          79          65          78
# TEMP             66 69 78 79 77 71 68 67 66 68 76 77 75 70 68 67 66 67 75 77 75
# DEWPT            61 62 61 60 60 60 61 61 61 61 62 61 61 61 61 61 61 62 62 62 61
# RH               84 78 56 52 56 68 78 81 84 78 62 58 62 73 78 81 84 84 64 60 62
# WIND DIR         NW  W  W  W  W SW SW SW  S  S SW SW SW SW  S  S  S  S SW SW SW
# WIND SPD          2  2  5  8  6  5  3  2  2  3  6  9  6  5  4  4  3  4  6  8  6
# CLOUDS           FW SC FW FW FW FW B2 OV B2 B1 FW FW FW FW B1 B1 B1 B1 FW FW FW
# POP 12HR                      0           0           0           0           0
# QPF 12HR                      0           0           0           0           0
# OBVIS               PF             PF PF PF PF             PF PF PF PF
#
#
# DATE               Sun 07/24/22  Mon 07/25/22  Tue 07/26/22  Wed 07/27/22
# PDT 6HRLY     23   05 11 17 23   05 11 17 23   05 11 17 23   05 11 17
# UTC 6HRLY     06   12 18 00 06   12 18 00 06   12 18 00 06   12 18 00
#
# MIN/MAX            65    77      64    77      65    78      65    78
# TEMP          67   66 74 73 66   65 74 74 67   66 75 74 67   66 75 74
# DEWPT         62   62 63 62 61   61 62 61 61   62 63 61 61   62 63 61
# PWIND DIR           W     W       W     W       W     W       W     W
# WIND CHAR          LT    LT      LT    LT      LT    LT      LT    LT
# AVG CLOUDS    FW   B1 B1 SC SC   B1 B1 B1 SC   B1 B1 B1 SC   B1 B1 SC
# POP 12HR            0    10       5    10       5    10      10     5
#
# $$
# CAZ043-220000-
# San Diego Lindbergh Field-San Diego CA
# 32.73N 117.18W ELEV. 30 FT
# 211 AM PDT Thu Jul 21 2022
#
# DATE                Thu 07/21/22            Fri 07/22/22            Sat 07/23/22
# PDT 3HRLY     02 05 08 11 14 17 20 23 02 05 08 11 14 17 20 23 02 05 08 11 14 17
# UTC 3HRLY     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# MAX/MIN                      73          64          72          64          72
# TEMP             66 68 71 72 70 67 66 65 65 66 69 70 69 67 66 65 64 66 69 70 70
# DEWPT            62 63 63 63 63 62 62 62 62 63 63 63 62 63 62 63 62 63 63 63 63
# RH               87 84 76 73 78 84 87 90 90 90 81 78 78 87 87 93 93 90 81 78 78
# WIND DIR         NW  W  W  W  W SW SW SW  S  S SW SW SW SW  S  S  S  S SW SW SW
# WIND SPD          2  3  6  9  6  4  3  2  2  4  6  8  6  4  4  4  4  5  6  6  5
# CLOUDS           SC B1 FW FW SC SC B2 OV B2 B2 SC SC SC SC B2 B2 B2 B2 FW FW SC
# POP 12HR                      0           0           0           0           0
# QPF 12HR                      0           0           0           0           0
# OBVIS            PF PF             PF PF PF PF             PF PF PF PF
# HIGH SURF         Y
#
#
# DATE               Sun 07/24/22  Mon 07/25/22  Tue 07/26/22  Wed 07/27/22
# PDT 6HRLY     23   05 11 17 23   05 11 17 23   05 11 17 23   05 11 17
# UTC 6HRLY     06   12 18 00 06   12 18 00 06   12 18 00 06   12 18 00
#
# MIN/MAX            65    70      65    71      65    71      65    71
# TEMP          66   65 68 68 66   66 69 68 65   65 69 69 66   66 69 69
# DEWPT         63   62 63 62 62   61 63 61 62   61 63 61 62   62 64 62
# PWIND DIR           W     W       W     W       W     W       W     W
# WIND CHAR          LT    LT      LT    LT      LT    LT      LT    LT
# AVG CLOUDS    SC   B2 B2 SC SC   B2 B2 B1 SC   B2 B2 SC SC   B2 B2 SC
# POP 12HR            0    10       5    10       5    10      10    10
#
# $$
# CAZ043-220000-
# Imperial Beach-San Diego CA
# 32.56N 117.11W ELEV. 26 FT
# 211 AM PDT Thu Jul 21 2022
#
# DATE                Thu 07/21/22            Fri 07/22/22            Sat 07/23/22
# PDT 3HRLY     02 05 08 11 14 17 20 23 02 05 08 11 14 17 20 23 02 05 08 11 14 17
# UTC 3HRLY     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# MAX/MIN                      74          64          72          64          72
# TEMP             66 69 71 72 70 68 66 65 65 67 70 71 69 67 66 65 65 67 69 71 70
# DEWPT            62 63 63 62 62 62 62 62 62 63 62 62 62 62 62 62 61 63 62 62 62
# RH               87 81 76 71 76 81 87 90 90 87 76 73 78 84 87 90 87 87 78 73 76
# WIND DIR         NW  W  W  W  W SW SW SW SW SW SW SW SW SW SW  S  S SW SW SW SW
# WIND SPD          2  3  8  9  8  6  4  3  3  5  9 10  8  6  5  6  5  6 10  9  8
# CLOUDS           SC B1 SC SC SC SC B2 B2 B2 B1 SC SC SC SC B2 B2 B2 B2 SC SC SC
# POP 12HR                      0           0           0           0           0
# QPF 12HR                      0           0           0           0           0
# OBVIS            PF PF             PF PF PF PF             PF PF PF PF
# HIGH SURF         Y
#
#
# DATE               Sun 07/24/22  Mon 07/25/22  Tue 07/26/22  Wed 07/27/22
# PDT 6HRLY     23   05 11 17 23   05 11 17 23   05 11 17 23   05 11 17
# UTC 6HRLY     06   12 18 00 06   12 18 00 06   12 18 00 06   12 18 00
#
# MIN/MAX            64    71      64    72      64    71      64    72
# TEMP          66   66 68 68 66   65 69 69 66   65 70 69 65   65 70 70
# DEWPT         62   62 62 61 61   62 62 61 61   61 63 60 62   61 63 61
# PWIND DIR           W     W       W     W       W     W       W     W
# WIND CHAR          LT    LT      LT    LT      LT    LT      LT    LT
# AVG CLOUDS    SC   B2 B2 SC SC   B1 B1 B1 SC   B2 B2 SC B1   B2 B2 SC
# POP 12HR            0    10       5    10       5    10       5    10
#
# $$
# CAZ043-220000-
# Brown Field-San Diego CA
# 32.58N 116.98W ELEV. 525 FT
# 211 AM PDT Thu Jul 21 2022
#
# DATE                Thu 07/21/22            Fri 07/22/22            Sat 07/23/22
# PDT 3HRLY     02 05 08 11 14 17 20 23 02 05 08 11 14 17 20 23 02 05 08 11 14 17
# UTC 3HRLY     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# MAX/MIN                      79          64          76          64          76
# TEMP             65 68 77 78 75 67 65 65 64 66 74 75 73 67 65 64 64 65 73 75 73
# DEWPT            62 62 62 60 61 61 62 62 61 62 62 62 61 61 62 62 62 62 63 62 62
# RH               90 81 60 54 62 81 90 90 90 87 66 64 66 81 90 93 93 90 71 64 68
# WIND DIR         NW  W  W  W  W  W  W  W NW  W  W  W  W  W  W  W SW SW  W  W  W
# WIND SPD          1  3  8 10  9  6  4  2  2  2  9 10  9  6  3  2  1  2  8 10  9
# CLOUDS           FW FW FW FW FW FW B1 B1 B1 B1 FW FW FW FW SC SC SC SC FW FW FW
# POP 12HR                      0           0           0           0           0
# QPF 12HR                      0           0           0           0           0
# OBVIS                              PF PF PF PF             PF PF PF PF
#
#
# DATE               Sun 07/24/22  Mon 07/25/22  Tue 07/26/22  Wed 07/27/22
# PDT 6HRLY     23   05 11 17 23   05 11 17 23   05 11 17 23   05 11 17
# UTC 6HRLY     06   12 18 00 06   12 18 00 06   12 18 00 06   12 18 00
#
# MIN/MAX            64    74      63    75      63    74      64    74
# TEMP          65   64 72 71 65   64 72 71 64   64 73 72 65   64 72 71
# DEWPT         62   62 62 63 61   62 62 62 61   61 63 62 62   62 63 63
# PWIND DIR           W     W       W     W       W     W       W     W
# WIND CHAR          LT    LT      LT    LT      LT    LT      LT    LT
# AVG CLOUDS    FW   B2 B2 SC B1   B1 B1 B1 SC   B1 B1 B1 B1   B1 B1 SC
# POP 12HR            0    10       5    10       5    10      10    10
#
# $$
# CAZ050-220000-
# Ramona-San Diego CA
# 33.04N 116.92W ELEV. 1394 FT
# 211 AM PDT Thu Jul 21 2022
#
# DATE                Thu 07/21/22            Fri 07/22/22            Sat 07/23/22
# PDT 3HRLY     02 05 08 11 14 17 20 23 02 05 08 11 14 17 20 23 02 05 08 11 14 17
# UTC 3HRLY     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# MAX/MIN                      91          62          91          61          90
# TEMP             64 73 85 90 87 75 67 64 63 71 85 90 86 74 67 64 63 70 84 89 86
# DEWPT            54 55 56 55 53 56 56 56 56 57 57 58 57 59 58 57 57 57 58 59 60
# RH               70 53 37 31 31 52 68 75 78 61 39 34 37 59 73 78 81 63 41 37 42
# WIND DIR         SE  W  W  W  W SW  W SE SE  S SW  W  W  W SW SW SE SW  W  W  W
# WIND SPD          1  2  8 10  9  4  3  1  1  1  6  9  9  4  1  1  1  1  6  9  9
# CLOUDS           FW SC FW FW FW FW FW FW SC SC FW FW FW FW FW FW SC SC FW FW FW
# POP 12HR                      0           0           0           0           0
# QPF 12HR                      0           0           0           0           0
#
#
# DATE               Sun 07/24/22  Mon 07/25/22  Tue 07/26/22  Wed 07/27/22
# PDT 6HRLY     23   05 11 17 23   05 11 17 23   05 11 17 23   05 11 17
# UTC 6HRLY     06   12 18 00 06   12 18 00 06   12 18 00 06   12 18 00
#
# MIN/MAX            62    89      61    87      62    86      61    87
# TEMP          67   63 82 83 66   63 81 82 66   63 81 82 66   62 80 81
# DEWPT         59   59 62 61 59   59 62 60 59   59 62 59 59   59 62 60
# PWIND DIR          SW    SW      SW     W       W     W       W     W
# WIND CHAR          LT    LT      LT    LT      LT    LT      LT    LT
# AVG CLOUDS    FW   FW FW SC SC   SC SC B1 SC   SC FW SC B1   SC SC B1
# POP 12HR            0    20       5    20      10    20      10    10
# RAIN SHWRS                S             S             S
# TSTMS                     S             S             S
#
# $$
# CAZ058-220000-
# Campo-San Diego CA
# 32.63N 116.47W ELEV. 2631 FT
# 211 AM PDT Thu Jul 21 2022
#
# DATE                Thu 07/21/22            Fri 07/22/22            Sat 07/23/22
# PDT 3HRLY     02 05 08 11 14 17 20 23 02 05 08 11 14 17 20 23 02 05 08 11 14 17
# UTC 3HRLY     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# MAX/MIN                      94          63          95          64          96
# TEMP             63 76 90 93 91 80 70 65 64 77 92 94 91 80 70 66 64 78 92 94 92
# DEWPT            47 48 46 50 51 52 51 48 47 48 45 51 53 54 52 48 46 47 43 50 54
# RH               56 37 22 23 26 38 51 54 54 36 20 23 28 41 53 52 52 33 18 23 28
# WIND DIR          S SW  W  W  W  W SW SW SE  S SW  W  W SW SW SW SE  S SW  W  W
# WIND SPD          4  5 10 13 13  8  4  3  2  2  9 12 12  8  2  2  1  1  9 12 12
# CLOUDS           SC FW FW FW FW FW FW SC SC SC FW FW FW FW FW FW SC SC FW FW FW
# POP 12HR                      5           0           0           0           5
# QPF 12HR                      0           0           0           0           0
#
#
# DATE               Sun 07/24/22  Mon 07/25/22  Tue 07/26/22  Wed 07/27/22
# PDT 6HRLY     23   05 11 17 23   05 11 17 23   05 11 17 23   05 11 17
# UTC 6HRLY     06   12 18 00 06   12 18 00 06   12 18 00 06   12 18 00
#
# MIN/MAX            64    93      65    90      63    89      62    88
# TEMP          70   64 90 88 69   65 87 85 68   63 86 85 67   62 85 85
# DEWPT         54   47 50 58 55   48 55 59 57   52 53 57 56   53 51 58
# PWIND DIR          SW     S      SW     E      SW    SW      SW    SW
# WIND CHAR          LT    LT      LT    LT      LT    LT      LT    LT
# AVG CLOUDS    FW   FW SC B1 B1   SC SC B1 B1   SC SC B1 B1   SC SC SC
# POP 12HR            5    20      10    20      10    20      20    10
# RAIN SHWRS                S             S             S  S
# TSTMS                     S             S             S  S
#
# $$
# CAZ061-220000-
# Palm Springs-Riverside CA
# 33.84N 116.50W ELEV. 479 FT
# 211 AM PDT Thu Jul 21 2022
#
# DATE                Thu 07/21/22            Fri 07/22/22            Sat 07/23/22
# PDT 3HRLY     02 05 08 11 14 17 20 23 02 05 08 11 14 17 20 23 02 05 08 11 14 17
# UTC 3HRLY     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# MAX/MIN                     114          87         115          86         112
# TEMP             89 92104111113106 99 93 90 93106112113106 99 92 88 91102108110
# DEWPT            53 53 49 47 47 50 49 52 53 53 48 47 47 50 50 51 54 53 50 47 50
# RH               29 27 16 12 11 16 19 25 28 26 15 12 11 16 19 25 31 28 18 13 14
# WIND DIR         NW  W  S NW NW NW NW NW NW NW  W NW NW NW NW NW NW  S SE  W  W
# WIND SPD         13 12  3 14 20 23 18 13 12  9  6 13 19 23 16 12 11  3  5  4 12
# WIND GUST                    32 34 28                31 34
# CLOUDS           FW FW FW FW FW FW FW FW FW FW FW FW FW FW SC SC SC SC FW FW FW
# POP 12HR                      0           0           0           0           0
# QPF 12HR                      0           0           0           0           0
# EXCESS HEAT             W  W  W  W  W  W  W  W  W  W  W
#
#
# DATE               Sun 07/24/22  Mon 07/25/22  Tue 07/26/22  Wed 07/27/22
# PDT 6HRLY     23   05 11 17 23   05 11 17 23   05 11 17 23   05 11 17
# UTC 6HRLY     06   12 18 00 06   12 18 00 06   12 18 00 06   12 18 00
#
# MIN/MAX            83   108      83   105      83   105      82   106
# TEMP          96   86 97105 94   85 95103 93   85 96103 93   84 96104
# DEWPT         51   60 60 58 57   64 61 59 57   60 60 57 56   60 55 52
# PWIND DIR           W     E      SW     E      NW     E       W     E
# WIND CHAR          GN    LT      LT    LT      LT    LT      LT    LT
# AVG CLOUDS    FW   FW FW SC SC   SC SC SC SC   SC SC SC SC   SC SC SC
# POP 12HR            0    20       5    20      10    20      10    10
# RAIN SHWRS                S             S             S
# TSTMS                     S             S             S
#
# $$
# CAZ061-220000-
# Thermal-Riverside CA
# 33.64N 116.17W ELEV. 112 FT
# 211 AM PDT Thu Jul 21 2022
#
# DATE                Thu 07/21/22            Fri 07/22/22            Sat 07/23/22
# PDT 3HRLY     02 05 08 11 14 17 20 23 02 05 08 11 14 17 20 23 02 05 08 11 14 17
# UTC 3HRLY     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# MAX/MIN                     114          85         115          84         111
# TEMP             87 94103111113104 97 92 87 95106112114104 96 91 86 92101108109
# DEWPT            53 57 56 53 51 54 53 53 54 56 54 51 50 54 54 53 56 57 57 53 55
# RH               31 29 21 15 13 19 23 27 32 27 18 14 12 19 25 28 36 31 24 17 17
# WIND DIR         NW  W SE  E  N  N NW NW NW  N SE SE SE  N NW NW NW SE SE SE SE
# WIND SPD         14  3  9  2  4 17 18 14 10  3  4  9  8 17 17 12  9  9  9  9  9
# WIND GUST                       27 29                   27 27
# CLOUDS           FW FW FW FW FW FW FW FW FW SC FW FW FW FW SC SC SC SC FW FW FW
# POP 12HR                      0           0           0           0           0
# QPF 12HR                      0           0           0           0           0
# EXCESS HEAT             W  W  W  W  W  W  W  W  W  W  W
#
#
# DATE               Sun 07/24/22  Mon 07/25/22  Tue 07/26/22  Wed 07/27/22
# PDT 6HRLY     23   05 11 17 23   05 11 17 23   05 11 17 23   05 11 17
# UTC 6HRLY     06   12 18 00 06   12 18 00 06   12 18 00 06   12 18 00
#
# MIN/MAX            81   106      82   103      81   104      81   103
# TEMP          94   84 97104 93   84 96102 92   83 95103 91   84 97102
# DEWPT         59   65 67 65 64   68 67 62 63   63 65 60 64   64 61 58
# PWIND DIR          SE    SE      SE    SE      SW    SE       W    SE
# WIND CHAR          LT    GN      GN    LT      LT    LT      LT    LT
# AVG CLOUDS    FW   FW SC SC FW   SC SC SC SC   SC SC SC SC   SC SC SC
# POP 12HR            0    20      10    20      10    20      10    10
# RAIN SHWRS                S             S             S
# TSTMS                     S             S             S
#
# $$

# %%
PFM = product_json['productText']

def returnthree_hr_timeseries_json_from_pfm(PFM):
    
    three_hr_timeseries_json = []
    location_coordinates = re.findall(r'.....N.......W E',PFM)
    location_texts = re.split(r'.....N.......W E', PFM)
    
    for index in range(len(location_coordinates)):
        
        time_series_dict = {}
        time_series_dict['location'] = location_coordinates[index]
        
        #date parser
        datesh = re.findall(r'Date         ................................................................', location_texts[1+index])
        if len(datesh) > 0:
            date3h = re.findall(r'Date         ...................',datesh[0])
            start_d = date3h[0].replace('Date         ','')
            start_date = start_d.replace('  ','')
            time_series_dict['start_date'] = start_date
        else:
            datesh = re.findall(r'DATE         ................................................................', location_texts[1+index])
            date3h = re.findall(r'DATE         ...................',datesh[0])
            start_d = date3h[0].replace('DATE         ','')
            start_date = start_d.replace('  ','')
            time_series_dict['start_date'] = start_date
            
        #hour parser
        hours3h = re.findall(r'T 3hrly     .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. ..',location_texts[1+index])
        if len(hours3h) > 0:
            hour_csv = hours3h[0].replace('T 3hrly     ','')
            hours = hour_csv.split(' ')
        else: 
            hours3h = re.findall(r'T 3HRLY     .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. ..',location_texts[1+index])
            hour_csv = hours3h[0].replace('T 3HRLY     ','')
            hours = hour_csv.split(' ')
            
        #go through hours and make them additional
        hours_added = []
        daycounter = 0
        lasthour = int(hours[0])
        for hour in hours:
            if int(hour) < lasthour:
                daycounter += 1
            hours_added.append(int(hour)+ daycounter * 24)
            lasthour = int(hour)
        
        #temp parser:
        
        temp = re.findall(r'Temp         ..................................................................', location_texts[1+index])
        if len(temp) > 0:
            forec = temp[0].replace('Temp         ','')
            temps = [forec[i:i+3] for i in range(0, len(forec), 3)]
        else:
            temp = re.findall(r'TEMP         ..................................................................', location_texts[1+index])
            forec = temp[0].replace('TEMP         ','')
            temps = [forec[i:i+3] for i in range(0, len(forec), 3)]
            
        #dew point parser:
        
        dew = re.findall(r'Dewpt         .................................................................', location_texts[1+index])
        if len(dew) > 0:
            dewp = dew[0].replace('Dewpt         ','')
            dewpoint = [dewp[i:i+3] for i in range(0, len(dewp), 3)]
        else:
            dew = re.findall(r'DEWPT         .................................................................', location_texts[1+index])
            dewp = dew[0].replace('DEWPT         ','')
            dewpoint = [dewp[i:i+3] for i in range(0, len(dewp), 3)]
            
        #wind direction parser:
        
        wind = re.findall(r'Wind dir      .................................................................', location_texts[1+index])
        if len(wind) > 0:
            windDi = wind[0].replace('Wind dir      ','')
            windDirection= [windDi[i:i+3] for i in range(0, len(windDi), 3)]
        else:
            wind = re.findall(r'WIND DIR      .................................................................', location_texts[1+index])
            windDi = wind[0].replace('WIND DIR      ','')
            windDirection= [windDi[i:i+3] for i in range(0, len(windDi), 3)]
            
        #windspeed parser:
        
        winds = re.findall(r'Wind spd      .................................................................',location_texts[1+index])
        if len(winds) > 0:
            windsp = winds[0].replace('Wind spd      ','')
            windSpeed = [windsp[i:i+3] for i in range(0, len(windsp), 3)]
        else:
            winds = re.findall(r'WIND SPD      .................................................................',location_texts[1+index])
            windsp = winds[0].replace('WIND SPD      ','')
            windSpeed = [windsp[i:i+3] for i in range(0, len(windsp), 3)]

        #clouds parser
        
        cl= re.findall(r'Clouds        .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. ..', location_texts[1+index])
        if len(cl) > 0:
            clo = cl[0].replace('Clouds        ','')
            clouds = [clo[i:i+3] for i in range(0, len(clo), 3)]
        else:
            cl= re.findall(r'CLOUDS        .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. ..', location_texts[1+index])
            clo = cl[0].replace('CLOUDS        ','')
            clouds = [clo[i:i+3] for i in range(0, len(clo), 3)]            
        
        #Relative humidity parser
        rh1 = re.findall(r'RH            .................................................................', location_texts[1+index])
        rh2 = rh1[0].replace('RH            ','')
        rh = [rh2[i:i+3] for i in range(0, len(rh2), 3)]
    
        
        #Probability of Precipitation: The next three items are not part of the 3 hour time series
        prec = re.findall(r'PoP 12hr                    ...................................................', location_texts[1+index])
        if len(prec)> 0:
            precip = prec[0].replace('PoP 12hr                     ','')
            precipit = precip.replace('          ',',')
            pop = precipit.split(',')
            time_series_dict['pop12H'] = pop
        else:
            prec = re.findall(r'POP 12HR                    ...................................................', location_texts[1+index])
            precip = prec[0].replace('POP 12HR                     ','')
            precipit = precip.replace('          ',',')
            pop = precipit.split(',')
            time_series_dict['pop12H'] = pop

            
        #Quantitative Precipitation Forecast
        quantit= re.findall(r'QPF 12hr                 ......      ......      ......      ......      ......',location_texts[1+index])
        if len(quantit) > 0:
            quantiprec = quantit[0].replace('QPF 12hr                 ','')
            quantiprecip = quantiprec.replace('      ',',')
            qpf = quantiprecip.split(',')
            time_series_dict['QPF12H'] = qpf
        else: 
            quantit= re.findall(r'QPF 12HR                 ......      ......      ......      ......      ......',location_texts[1+index])
            quantiprec = quantit[0].replace('QPF 12HR                 ','')
            quantiprecip = quantiprec.replace('      ',',')
            qpf = quantiprecip.split(',')
            time_series_dict['QPF12H'] = qpf
            
        #Not all of the stations measure the probability of snow e.g. Phoenix, Houston. If your PFM doesn't contain this part of
        #the include an if to check the snow
 
        s = re.findall(r'Snow 12hr                .......     .......     .......                       ',location_texts[1+index])
        if len(s) > 0:
            snow = s[0].replace('Snow 12hr                 ','')
            snow1 = snow.replace('                        ','')
            snow12 = snow1.replace('       ',',')
            snow12h = snow12.split(',')
            time_series_dict['Snow12H'] = snow12h
        
        s = re.findall(r'SNOW 12HR                .......     .......     .......                       ',location_texts[1+index])
        if len(s) > 0:
            snow = s[0].replace('SNOW 12HR                 ','')
            snow1 = snow.replace('                        ','')
            snow12 = snow1.replace('       ',',')
            snow12h = snow12.split(',')
            time_series_dict['Snow12H'] = snow12h

        #align hour and temps
        
        ts = []
        
        for index2 in range(len(temps)):

            ts.append([hours_added[index2],temps[index2],dewpoint[index2], rh[index2], windDirection[index2], windSpeed[index2], clouds[index2]])
        time_series_dict['timeseries'] = ts
        three_hr_timeseries_json.append(time_series_dict)
        
    return three_hr_timeseries_json
 
        
fresh_json = returnthree_hr_timeseries_json_from_pfm(PFM)
print(fresh_json[0:20])
# Out:
# [{'location': '33.68N 117.87W E', 'start_date': ' Thu 07/21/22', 'pop12H': [' 0', ' 0', ' 0', ' 0', ' 0'], 'QPF12H': ['     0', '     0', '     0', '     0', '     0'], 'timeseries': [[2, '   ', '   ', '   ', '   ', '   ', '   