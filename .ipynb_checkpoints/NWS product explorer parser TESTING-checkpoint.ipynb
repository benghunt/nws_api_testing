# %%
import requests, json
import re
from datetime import datetime

# %%
apistarturl = 'https://api.weather.gov'

def get_location_url_from_coords(lat,lon):
    return apistarturl + '/points/' + str(lat) + ',' + str(lon)


#HERE IS WHERE YOU CHANGE THE LAT / LON OF THE AREA YOU ARE INTERESTED IN

url = get_location_url_from_coords(29.9511,-90.0715)

#NEW ORLEANS IS USED AS THE DEFAULT 29.9511,-90.0715

print(url)
# Out:
# https://api.weather.gov/points/29.9511,-90.0715

# %%
r = requests.get(url)
print(r)
# Out:
# <Response [200]>

# %%
location_json_obj = json.loads(r.text)
print(location_json_obj.keys())
print(location_json_obj['properties'].keys())
# Out:
# dict_keys(['@context', 'id', 'type', 'geometry', 'properties'])
# dict_keys(['@id', '@type', 'cwa', 'forecastOffice', 'gridId', 'gridX', 'gridY', 'forecast', 'forecastHourly', 'forecastGridData', 'observationStations', 'relativeLocation', 'forecastZone', 'county', 'fireWeatherZone', 'timeZone', 'radarStation'])

# %%
office = location_json_obj['properties']['gridId']
station = 'K'+ office
print(office)
print(station)
products_in_station_url = apistarturl + '/products/locations/' + office + '/types'
print(products_in_station_url)
r = requests.get(products_in_station_url)
print(r)
# Out:
# LIX
# KLIX
# https://api.weather.gov/products/locations/LIX/types
# <Response [200]>

# %%
products_at_station = json.loads(r.text)['@graph']
products_at_station
# Out:
# [{'productCode': 'ABV', 'productName': 'Rawinsonde Data Above 100 Millibars'},
#  {'productCode': 'AFD', 'productName': 'Area Forecast Discussion'},
#  {'productCode': 'CWF', 'productName': 'Coastal Waters Forecast'},
#  {'productCode': 'FFW', 'productName': 'Flash Flood Warning'},
#  {'productCode': 'FLS', 'productName': 'Flood Statement'},
#  {'productCode': 'FWF',
#   'productName': 'Routine Fire Wx Fcst (With/Without 6-10 Day Outlook)'},
#  {'productCode': 'FWM', 'productName': 'Miscellaneous Fire Weather Product'},
#  {'productCode': 'FWN', 'productName': 'Fire Weather Notification'},
#  {'productCode': 'FWO', 'productName': 'Fire Weather Observation'},
#  {'productCode': 'FZL', 'productName': 'Freezing Level Data (RADAT)'},
#  {'productCode': 'HML', 'productName': 'AHPS XML'},
#  {'productCode': 'LSR', 'productName': 'Local Storm Report'},
#  {'productCode': 'MAN',
#   'productName': 'Rawinsonde Observation Mandatory Levels'},
#  {'productCode': 'MWS', 'productName': 'Marine Weather Statement'},
#  {'productCode': 'NPW',
#   'productName': 'Non-Precipitation Warnings / Watches / Advisories'},
#  {'productCode': 'OSO', 'productName': 'Other Surface Observations'},
#  {'productCode': 'PFM', 'productName': 'Point Forecast Matrices'},
#  {'productCode': 'PFW', 'productName': 'Fire Weather Point Forecast Matrices'},
#  {'productCode': 'RRM', 'productName': 'Miscellaneous Hydrologic Data'},
#  {'productCode': 'RRS', 'productName': 'HADS Data'},
#  {'productCode': 'RTP',
#   'productName': 'Regional Max/Min Temp and Precipitation Table'},
#  {'productCode': 'RVD', 'productName': 'Daily River Forecasts'},
#  {'productCode': 'RVF', 'productName': 'River Forecast'},
#  {'productCode': 'RVS', 'productName': 'River Statement'},
#  {'productCode': 'RWR', 'productName': 'Regional Weather Roundup'},
#  {'productCode': 'SFT', 'productName': 'Tabular State Forecast'},
#  {'productCode': 'SGL',
#   'productName': 'Rawinsonde Observation Significant Levels'},
#  {'productCode': 'SMW', 'productName': 'Special Marine Warning'},
#  {'productCode': 'SPS', 'productName': 'Special Weather Statement'},
#  {'productCode': 'SVR', 'productName': 'Severe Thunderstorm Warning'},
#  {'productCode': 'SVS', 'productName': 'Severe Weather Statement'},
#  {'productCode': 'TID', 'productName': 'Tide Report'},
#  {'productCode': 'VFT',
#   'productName': 'Terminal Aerodrome Forecast (TAF) Verification'},
#  {'productCode': 'ZFP', 'productName': 'Zone Forecast Product'}]

# %%
#THIS IS AN IMPORTANT LINE
#v v v v vv v v v v v v v  
desired_product_code = 'PFM'
# ^ ^ ^ ^ ^ ^ ^ ^ ^ ^ ^ ^
#HERE IS WHERE YOU CHANGE THE PRODUCT CODE TO BE THE THREE LETTER PRODUCT OF INTEREST

for product in products_at_station:
    if product['productCode'] == desired_product_code:
        print(product)
recentProductURL = apistarturl + '/products/types/' + desired_product_code
print(recentProductURL)
r = requests.get(recentProductURL)
print(r)
# Out:
# {'productCode': 'PFM', 'productName': 'Point Forecast Matrices'}
# https://api.weather.gov/products/types/PFM
# <Response [200]>

# %%
recentProductURL = apistarturl + '/products/types/' + desired_product_code
recentProductURL
# Out:
# 'https://api.weather.gov/products/types/PFM'

# %%
recentProductsJSON = json.loads(r.text)
print(recentProductsJSON.keys())
station_products = []
for product in recentProductsJSON['@graph']:
    if product['issuingOffice'] == station:
        station_products.append(product)
station_products[0]
# Out:
# dict_keys(['@context', '@graph'])
# {'@id': 'https://api.weather.gov/products/93aa012d-17cc-4f95-96bd-1bb963a1d811',
#  'id': '93aa012d-17cc-4f95-96bd-1bb963a1d811',
#  'wmoCollectiveId': 'FOUS54',
#  'issuingOffice': 'KLIX',
#  'issuanceTime': '2022-07-19T09:17:00+00:00',
#  'productCode': 'PFM',
#  'productName': 'Point Forecast Matrices'}

# %%
#HERE IS WHERE THE PRODUCTS AVAILABLE ARE REDUCED TO THE MOST RECENT ONE

t1 = datetime.strptime(station_products[0]['issuanceTime'].split('+')[0], '%Y-%m-%dT%H:%M:%S')
t2 = datetime.strptime(station_products[1]['issuanceTime'].split('+')[0], '%Y-%m-%dT%H:%M:%S')
most_recent_date = datetime(1,1,1)
most_recent_product = ''
for product in station_products:
    product_date = datetime.strptime(product['issuanceTime'].split('+')[0], '%Y-%m-%dT%H:%M:%S')
    if most_recent_date < product_date:
        most_recent_product = product
        most_recent_date = product_date

# %%
most_recent_product
# Out:
# {'@id': 'https://api.weather.gov/products/93aa012d-17cc-4f95-96bd-1bb963a1d811',
#  'id': '93aa012d-17cc-4f95-96bd-1bb963a1d811',
#  'wmoCollectiveId': 'FOUS54',
#  'issuingOffice': 'KLIX',
#  'issuanceTime': '2022-07-19T09:17:00+00:00',
#  'productCode': 'PFM',
#  'productName': 'Point Forecast Matrices'}

# %%
most_recent_product_url = most_recent_product['@id']

# %%
r =requests.get(most_recent_product_url)
print(r)
product_json = json.loads(r.text)
print(product_json.keys())
# Out:
# <Response [200]>
# dict_keys(['@context', '@id', 'id', 'wmoCollectiveId', 'issuingOffice', 'issuanceTime', 'productCode', 'productName', 'productText'])

# %%
print(product_json['productText'])
# Out:
# 000
# FOUS54 KLIX 190917
# PFMLIX
#
# Point Forecast Matrices
# National Weather Service New Orleans LA
# 417 AM CDT Tue Jul 19 2022
#
# MSZ070-192200-
# McComb-Pike MS
# 31.18N  90.47W Elev. 424 ft
# 417 AM CDT Tue Jul 19 2022
#
# Date             Tue 07/19/22            Wed 07/20/22            Thu 07/21/22
# CDT 3hrly     04 07 10 13 16 19 22 01 04 07 10 13 16 19 22 01 04 07 10 13 16 19
# UTC 3hrly     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# Max/Min                      94          74          96          76          94
# Temp             75 82 88 94 86 80 78 76 76 84 90 96 89 81 78 77 77 84 89 94 85
# Dewpt            73 74 73 72 73 73 73 73 73 75 74 71 72 74 74 73 74 75 74 73 74
# RH               94 77 61 49 65 79 85 90 90 74 60 45 57 79 88 87 90 74 61 51 70
# Wind dir         SW SW SW SW  S  S SW SW SW SW SW SW SW SW SW SW SW  W SW SW SW
# Wind spd          4 12 11 11 12  8  6  6  4 12 12 12 10  6  6  6  5 10  8  9  9
# Clouds           FW SC SC SC SC SC FW SC SC SC SC SC SC FW FW SC SC SC B1 B1 B1
# PoP 12hr                     20           5          10           5          40
# QPF 12hr                      0           0           0           0           0
# Snow 12hr                 00-00       00-00       00-00
# Rain shwrs                 S                                            C  C  S
# Tstms                      S                                            C  C  S
# Heat index          88 96102 93 84          92 99104 96 86          92 98103 93
# Max heat               96   102    91          99   104    93          98   103
# Heat                    Y  Y
#
#
# Date          Fri 07/22/22  Sat 07/23/22  Sun 07/24/22  Mon 07/25/22
# CDT 6hrly     01 07 13 19   01 07 13 19   01 07 13 19   01 07 13 19
# UTC 6hrly     06 12 18 00   06 12 18 00   06 12 18 00   06 12 18 00
#
# Min/Max          74    93      73    93      73    94      74    95
# Temp          77 76 89 83   76 74 90 85   76 75 90 86   77 75 92 86
# Dewpt         73 73 74 74   72 72 74 73   73 73 73 72   73 73 73 73
# PWind dir        SW    SW       S     S       S     S       S     S
# Wind char        LT    LT      LT    LT      LT    LT      LT    LT
# Avg clouds    B1 SC SC B2   B1 SC SC B1   SC FW FW SC   FW FW SC SC
# PoP 12hr         20    60       5    40       5    30       5    30
# Rain shwrs     S     C  L             C             C             C
# Tstms          S     C  L             C             C             C
#
# $$
# LAZ048-192200-
# Baton Rouge-East Baton Rouge LA
# 30.53N  91.15W Elev. 64 ft
# 417 AM CDT Tue Jul 19 2022
#
# Date             Tue 07/19/22            Wed 07/20/22            Thu 07/21/22
# CDT 3hrly     04 07 10 13 16 19 22 01 04 07 10 13 16 19 22 01 04 07 10 13 16 19
# UTC 3hrly     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# Max/Min                      95          77          97          78          96
# Temp             78 85 90 95 88 82 79 78 79 87 92 97 90 83 81 79 79 86 91 96 87
# Dewpt            75 76 75 75 74 75 75 75 76 77 75 74 75 76 76 76 77 77 75 74 75
# RH               91 75 62 53 63 79 88 91 91 72 58 48 62 80 85 91 94 75 60 49 68
# Wind dir         SW SW SW SW SW SW SW SW SW SW SW SW SW SW SW SW SW  W SW SW SW
# Wind spd          4 11 11 14 13 12  9  8  5 11 11 16 12 12  9  6  4 10  9 11  9
# Clouds           FW SC SC B1 SC SC SC SC FW SC SC SC FW FW FW SC SC SC B1 B1 B1
# PoP 12hr                     20           0          20           5          50
# QPF 12hr                      0           0           0           0        0.01
# Snow 12hr                 00-00       00-00       00-00
# Rain shwrs                 S                    S  S                    C  C
# Tstms                      S                    S  S                    C  C
# Heat index          94101107 97 89          99103109101 91 87       97102107 96
# Max heat              101   107    95         103   109    96    86   102   107
# Heat                    Y  Y
#
#
# Date          Fri 07/22/22  Sat 07/23/22  Sun 07/24/22  Mon 07/25/22
# CDT 6hrly     01 07 13 19   01 07 13 19   01 07 13 19   01 07 13 19
# UTC 6hrly     06 12 18 00   06 12 18 00   06 12 18 00   06 12 18 00
#
# Min/Max          76    94      75    96      75    95      75    96
# Temp          79 78 91 83   78 77 91 85   79 77 91 85   79 77 92 87
# Dewpt         75 76 75 75   75 75 75 75   75 76 74 74   75 76 74 74
# PWind dir        SW    SW       S     S       S     S       S     S
# Wind char        LT    LT      LT    LT      LT    LT      LT    LT
# Avg clouds    SC SC SC B2   SC SC SC B1   SC FW SC B1   FW FW SC B1
# PoP 12hr          5    60       5    50       5    30       5    40
# Rain shwrs           S  L             C             C             C
# Tstms                S  L             C             C             C
#
# $$
# LAZ076-192200-
# Slidell-Southeast St Tammany LA
# 30.25N  89.77W Elev. 29 ft
# 417 AM CDT Tue Jul 19 2022
#
# Date             Tue 07/19/22            Wed 07/20/22            Thu 07/21/22
# CDT 3hrly     04 07 10 13 16 19 22 01 04 07 10 13 16 19 22 01 04 07 10 13 16 19
# UTC 3hrly     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# Max/Min                      94          77          96          78          95
# Temp             79 86 90 94 88 83 81 79 79 88 92 96 89 83 81 79 79 85 90 95 88
# Dewpt            74 75 74 74 75 75 74 74 74 75 74 74 75 76 75 74 75 75 75 75 75
# RH               85 70 60 53 66 77 79 85 85 66 56 49 64 80 82 85 88 72 62 53 66
# Wind dir         SW SW SW SW SW SW SW SW SW SW SW SW SW SW SW SW SW  W SW SW SW
# Wind spd          3  9  9 13 10  6  6  6  4  9 11 13 10  6  6  5  4  8  9 11  8
# Clouds           SC SC SC SC SC SC SC SC SC FW SC SC SC FW SC SC SC SC B1 B1 SC
# PoP 12hr                     30           5          30           5          50
# QPF 12hr                      0           0           0           0        0.01
# Snow 12hr                 00-00       00-00       00-00
# Rain shwrs           S  S  C                    C  C              S  S  C  C
# Tstms                S  S  C                    C  C              S  S  C  C
# Heat index          95 99105 98 90 86       98102107 99 91 87       94101107 98
# Max heat               99   105    95    84   102   107    96    85   101   107
# Heat                    Y  Y
#
#
# Date          Fri 07/22/22  Sat 07/23/22  Sun 07/24/22  Mon 07/25/22
# CDT 6hrly     01 07 13 19   01 07 13 19   01 07 13 19   01 07 13 19
# UTC 6hrly     06 12 18 00   06 12 18 00   06 12 18 00   06 12 18 00
#
# Min/Max          76    93      76    94      75    94      76    95
# Temp          80 78 89 84   79 78 91 86   79 77 90 86   79 78 92 87
# Dewpt         75 74 75 75   74 74 74 74   74 73 74 74   75 74 74 74
# PWind dir        SW    SW       S     S       S     S       S     S
# Wind char        LT    LT      LT    LT      LT    LT      LT    LT
# Avg clouds    SC SC B1 B2   SC SC SC B1   SC FW SC B1   FW FW SC B1
# PoP 12hr         10    60       5    50       5    40       5    40
# Rain shwrs           C  L          S  C             C             C
# Tstms                C  L          S  C             C             C
#
# $$
# LAZ077-192200-
# New Orleans-Western Orleans LA
# 30.00N  90.25W Elev. 11 ft
# 417 AM CDT Tue Jul 19 2022
#
# Date             Tue 07/19/22            Wed 07/20/22            Thu 07/21/22
# CDT 3hrly     04 07 10 13 16 19 22 01 04 07 10 13 16 19 22 01 04 07 10 13 16 19
# UTC 3hrly     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# Max/Min                      93          79          95          80          94
# Temp             80 86 90 93 88 83 81 80 81 88 92 95 88 83 82 81 81 86 90 94 87
# Dewpt            77 76 75 75 76 76 76 77 77 77 75 75 75 76 77 77 77 77 76 76 76
# RH               91 72 62 56 68 80 85 91 88 70 58 53 66 80 85 88 88 75 64 56 70
# Wind dir         SW SW SW SW SW SW SW SW SW SW SW SW SW SW SW SW SW  W SW SW SW
# Wind spd          5 10 12 13 12  9  9  6  6 11 12 14 13 10  9  6  5  9 10 11 10
# Clouds           SC SC SC B1 SC SC FW SC SC SC SC SC SC SC SC SC SC SC B2 B2 B1
# PoP 12hr                     30           5          30           5          50
# QPF 12hr                   0.04           0           0           0        0.04
# Snow 12hr                 00-00       00-00       00-00
# Rain shwrs           S  C  C                    C  C              S  S  C  C
# Tstms                S  C  C                    C  C              S  S  C  C
# Heat index       87 96101105 99 91 87 87 88100103107 98 91 90 88 88 97102107 98
# Max heat         87   101   105    96    88   103   107    95    90   102   107
#
#
# Date          Fri 07/22/22  Sat 07/23/22  Sun 07/24/22  Mon 07/25/22
# CDT 6hrly     01 07 13 19   01 07 13 19   01 07 13 19   01 07 13 19
# UTC 6hrly     06 12 18 00   06 12 18 00   06 12 18 00   06 12 18 00
#
# Min/Max          79    91      79    92      78    92      78    93
# Temp          81 81 87 84   81 81 88 85   81 81 88 85   81 80 89 86
# Dewpt         77 77 75 75   77 77 76 76   77 77 75 76   77 77 75 75
# PWind dir        SW     S       S    SE       S    SE       S    SE
# Wind char        LT    LT      LT    LT      LT    GN      LT    GN
# Avg clouds    SC SC B1 B2   SC SC SC B1   FW SC SC B1   SC SC SC B1
# PoP 12hr         10    60       5    50       5    40       5    40
# Rain shwrs           C  L          S  C          S  C          S  C
# Tstms                C  L          S  C          S  C          S  C
#
# $$
# LAZ078-192200-
# East New Orleans-Eastern Orleans LA
# 30.07N  89.93W Elev. 11 ft
# 417 AM CDT Tue Jul 19 2022
#
# Date             Tue 07/19/22            Wed 07/20/22            Thu 07/21/22
# CDT 3hrly     04 07 10 13 16 19 22 01 04 07 10 13 16 19 22 01 04 07 10 13 16 19
# UTC 3hrly     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# Max/Min                      91          79          92          79          91
# Temp             80 86 88 91 87 83 81 80 81 87 89 92 87 83 82 81 81 85 88 91 87
# Dewpt            76 77 76 77 77 77 76 76 77 77 76 77 77 77 77 77 77 78 76 77 77
# RH               88 75 68 64 72 82 85 88 88 72 66 62 72 82 85 88 88 80 68 64 72
# Wind dir         SW SW  W  S SW SW SW SW SW SW SW SW SW SW SW SW SW  W SW SW SW
# Wind spd          8  9 10 12 12 10  9  8  9 10 11 13 11 11 10  8  8  9  9 11 10
# Clouds           SC SC SC B1 B1 FW SC SC SC FW SC SC SC SC SC SC SC SC B1 B1 B1
# PoP 12hr                     30           5          20           5          50
# QPF 12hr                   0.17        0.05        0.02           0        0.01
# Snow 12hr                 00-00       00-00       00-00
# Rain shwrs        S  S  C  C                    S  S              S  S  C  C
# Tstms             S  S  C  C                    S  S              S  S  C  C
# Heat index       86 97 99105 99 92 87 86 88 99100106 99 92 90 88 88 97 99105 99
# Max heat         86    99   105    96    88   102   106    97    90    99   105
#
#
# Date          Fri 07/22/22  Sat 07/23/22  Sun 07/24/22  Mon 07/25/22
# CDT 6hrly     01 07 13 19   01 07 13 19   01 07 13 19   01 07 13 19
# UTC 6hrly     06 12 18 00   06 12 18 00   06 12 18 00   06 12 18 00
#
# Min/Max          79    90      79    90      79    90      79    90
# Temp          81 81 86 85   81 81 87 85   81 81 87 85   81 81 87 86
# Dewpt         77 77 76 76   76 77 76 77   77 77 76 76   77 77 76 76
# PWind dir        SW     S       S    SE       S    SE       S    SE
# Wind char        LT    GN      LT    LT      LT    LT      LT    GN
# Avg clouds    SC SC B1 B2   B1 SC SC B1   SC SC SC B1   SC FW SC B1
# PoP 12hr         10    50       5    40       5    30       5    30
# Rain shwrs           C  C          S  C             C          S  C
# Tstms                C  C          S  C             C          S  C
#
# $$
# MSZ081-192200-
# Gulfport-Harrison MS
# 30.42N  89.08W Elev. 29 ft
# 417 AM CDT Tue Jul 19 2022
#
# Date             Tue 07/19/22            Wed 07/20/22            Thu 07/21/22
# CDT 3hrly     04 07 10 13 16 19 22 01 04 07 10 13 16 19 22 01 04 07 10 13 16 19
# UTC 3hrly     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# Max/Min                      90          79          91          79          92
# Temp             79 85 87 90 86 84 81 80 80 87 89 91 87 84 82 80 80 85 89 92 88
# Dewpt            76 76 76 76 76 77 76 76 77 77 76 76 77 77 77 76 77 77 76 76 77
# RH               91 75 70 64 72 80 85 88 91 72 66 62 72 80 85 88 91 77 66 60 70
# Wind dir          W SW SW  S  S SW SW SW  W SW SW  S SW SW SW SW SW SW SW  S SW
# Wind spd          5 10 12 13 12 11 10  8  6 12 12 13 12 11 10  8  6 10 10 12  9
# Clouds           SC SC SC SC B1 SC SC SC SC SC SC SC SC SC SC SC SC SC B1 B1 B1
# PoP 12hr                     30          10          30          10          50
# QPF 12hr                      0           0        0.01           0           0
# Snow 12hr                 00-00       00-00       00-00
# Rain shwrs           S  S  C                    C  C              C  C  C  C
# Tstms                S  S  C                    C  C              S  C  C  C
# Heat index          94 98102 96 94 87 86 87 99100103 99 94 90 86 87 96100105100
# Max heat               98   102    96    87   100   103    97    88   100   105
#
#
# Date          Fri 07/22/22  Sat 07/23/22  Sun 07/24/22  Mon 07/25/22
# CDT 6hrly     01 07 13 19   01 07 13 19   01 07 13 19   01 07 13 19
# UTC 6hrly     06 12 18 00   06 12 18 00   06 12 18 00   06 12 18 00
#
# Min/Max          78    90      77    90      77    90      78    90
# Temp          81 79 87 85   80 79 89 86   80 78 89 86   80 79 90 87
# Dewpt         77 76 76 76   76 75 76 76   76 76 76 76   76 76 76 75
# PWind dir        SW    SW       S     S       S     S      SW     S
# Wind char        LT    LT      LT    LT      LT    LT      LT    LT
# Avg clouds    SC SC B1 B2   B1 SC SC B1   SC FW SC SC   FW FW SC B1
# PoP 12hr         20    60       5    40       5    30       5    30
# Rain shwrs        S  C  L          S  C             C             C
# Tstms             S  C  L          S  C             C             C
#
# $$
# MSZ082-192200-
# Pascagoula-Jackson MS
# 30.47N  88.53W Elev. 12 ft
# 417 AM CDT Tue Jul 19 2022
#
# Date             Tue 07/19/22            Wed 07/20/22            Thu 07/21/22
# CDT 3hrly     04 07 10 13 16 19 22 01 04 07 10 13 16 19 22 01 04 07 10 13 16 19
# UTC 3hrly     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00
#
# Max/Min                      91          78          91          78          92
# Temp             79 84 87 91 85 81 81 79 79 87 89 91 86 82 81 79 80 84 88 92 86
# Dewpt            77 78 77 78 77 77 76 76 77 78 78 78 77 78 77 76 77 78 77 78 77
# RH               94 82 72 66 77 88 85 91 94 75 70 66 75 88 88 91 91 82 70 64 75
# Wind dir          W SW SW SW SW SW SW  W  W  W SW SW SW SW SW SW  W  W SW SW SW
# Wind spd          4  8 11 13 11  9  8  8  5 11 13 13 11 10 10  8  6  8 10 12 10
# Clouds           SC SC SC B1 SC SC SC SC SC SC B1 B1 SC SC SC SC B1 B1 B1 B1 B1
# PoP 12hr                     30          20          30          10          50
# QPF 12hr                   0.02           0        0.02           0        0.01
# Snow 12hr                 00-00       00-00       00-00
# Rain shwrs           S  S  C           S  S  S  C  C              C  C  C  C
# Tstms                S  S  C           S  S  S  C  C              C  C  C  C
# Heat index          95 99106 96 88 87      100103106 97 91 88    87 95100107 97
# Max heat               99   106    94    86   103   106    96    87   100   107
#
#
# Date          Fri 07/22/22  Sat 07/23/22  Sun 07/24/22  Mon 07/25/22
# CDT 6hrly     01 07 13 19   01 07 13 19   01 07 13 19   01 07 13 19
# UTC 6hrly     06 12 18 00   06 12 18 00   06 12 18 00   06 12 18 00
#
# Min/Max          77    90      77    91      75    92      76    92
# Temp          80 79 87 83   79 79 90 85   79 78 89 85   78 78 90 85
# Dewpt         76 77 77 76   75 76 76 76   75 77 77 76   75 76 76 76
# PWind dir        SW    SW       S     S       S     S      SW     S
# Wind char        LT    LT      LT    LT      LT    LT      LT    LT
# Avg clouds    SC SC B1 B2   B1 SC SC B1   FW FW SC B1   FW FW SC B1
# PoP 12hr         20    60      10    40       5    30       5    30
# Rain shwrs        S  C  L          S  C             C             C
# Tstms             S  C  L          S  C             C             C
#
# $$

# %%
product_json['productText']
# Out:
# '\n000\nFOUS54 KLIX 190917\nPFMLIX\n\nPoint Forecast Matrices\nNational Weather Service New Orleans LA\n417 AM CDT Tue Jul 19 2022\n\nMSZ070-192200-\nMcComb-Pike MS \n31.18N  90.47W Elev. 424 ft\n417 AM CDT Tue Jul 19 2022\n\nDate             Tue 07/19/22            Wed 07/20/22            Thu 07/21/22\nCDT 3hrly     04 07 10 13 16 19 22 01 04 07 10 13 16 19 22 01 04 07 10 13 16 19\nUTC 3hrly     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00\n\nMax/Min                      94          74          96          76          94\nTemp             75 82 88 94 86 80 78 76 76 84 90 96 89 81 78 77 77 84 89 94 85\nDewpt            73 74 73 72 73 73 73 73 73 75 74 71 72 74 74 73 74 75 74 73 74\nRH               94 77 61 49 65 79 85 90 90 74 60 45 57 79 88 87 90 74 61 51 70\nWind dir         SW SW SW SW  S  S SW SW SW SW SW SW SW SW SW SW SW  W SW SW SW\nWind spd          4 12 11 11 12  8  6  6  4 12 12 12 10  6  6  6  5 10  8  9  9\nClouds           FW SC SC SC SC SC FW SC SC SC SC SC SC FW FW SC SC SC B1 B1 B1\nPoP 12hr                     20           5          10           5          40\nQPF 12hr                      0           0           0           0           0\nSnow 12hr                 00-00       00-00       00-00                        \nRain shwrs                 S                                            C  C  S\nTstms                      S                                            C  C  S\nHeat index          88 96102 93 84          92 99104 96 86          92 98103 93\nMax heat               96   102    91          99   104    93          98   103\nHeat                    Y  Y                                                   \n\n\nDate          Fri 07/22/22  Sat 07/23/22  Sun 07/24/22  Mon 07/25/22\nCDT 6hrly     01 07 13 19   01 07 13 19   01 07 13 19   01 07 13 19\nUTC 6hrly     06 12 18 00   06 12 18 00   06 12 18 00   06 12 18 00\n\nMin/Max          74    93      73    93      73    94      74    95\nTemp          77 76 89 83   76 74 90 85   76 75 90 86   77 75 92 86\nDewpt         73 73 74 74   72 72 74 73   73 73 73 72   73 73 73 73\nPWind dir        SW    SW       S     S       S     S       S     S\nWind char        LT    LT      LT    LT      LT    LT      LT    LT\nAvg clouds    B1 SC SC B2   B1 SC SC B1   SC FW FW SC   FW FW SC SC\nPoP 12hr         20    60       5    40       5    30       5    30\nRain shwrs     S     C  L             C             C             C\nTstms          S     C  L             C             C             C\n\n$$\nLAZ048-192200-\nBaton Rouge-East Baton Rouge LA \n30.53N  91.15W Elev. 64 ft\n417 AM CDT Tue Jul 19 2022\n\nDate             Tue 07/19/22            Wed 07/20/22            Thu 07/21/22\nCDT 3hrly     04 07 10 13 16 19 22 01 04 07 10 13 16 19 22 01 04 07 10 13 16 19\nUTC 3hrly     09 12 15 18 21 00 03 06 09 12 15 18 21 00 03 06 09 12 15 18 21 00\n\nMax/Min                      95          77          97          78          96\nTemp             78 85 90 95 88 82 79 78 79 87 92 97 90 83 81 79 79 86 91 96 87\nDewpt            75 76 75 75 74 75 75 75 76 77 75 74 75 76 76 76 77 77 75 74 75\nRH               91 75 62 53 63 79 88 91 91 72 58 48 62 80 85 91 94 75 60 49 68\nWind dir         SW SW SW SW SW SW SW SW SW SW SW SW SW SW SW SW SW  W SW SW SW\nWind spd          4 11 11 14 13 12  9  8  5 11 11 16 12 12  9  6  4 10  9 11  9\nClouds           FW SC SC B1 SC SC SC SC FW SC SC SC FW FW FW SC SC SC B1 B1 B1\nPoP 12hr                     20           0          20           5          50\nQPF 12hr                      0           0           0           0        0.01\nSnow 12hr                 00-00       00-00       00-00                        \nRain shwrs                 S                    S  S                    C  C   \nTstms                      S                    S  S                    C  C   \nHeat index          94101107 97 89          99103109101 91 87       97102107 96\nMax heat              101   107    95         103   109    96    86   1 ...

# %%
PFM = product_json['productText']

def returnthree_hr_timeseries_json_from_pfm(PFM):
    
    three_hr_timeseries_json = []
    location_coordinates = re.findall(r'.....N.......W E',PFM)
    location_texts = re.split(r'.....N.......W E', PFM)
    print(location_coordinates)
    
    for index in range(len(location_coordinates)):
        
        time_series_dict = {}
        time_series_dict['location'] = location_coordinates[index]
        
        #date parser
        datesh = re.findall(r'Date         ................................................................', location_texts[1+index])
        date3h = re.findall(r'Date         ...................',datesh[0])
        start_d = date3h[0].replace('Date         ','')
        start_date = start_d.replace('  ','')
        time_series_dict['start_date'] = start_date

        #hour parser
        hours3h = re.findall(r'T 3hrly     .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. ..',location_texts[1+index])
        hour_csv = hours3h[0].replace('T 3hrly     ','')
        hours = hour_csv.split(' ')
        
        #go through hours and make them additional
        hours_added = []
        daycounter = 0
        lasthour = int(hours[0])
        for hour in hours:
            if int(hour) < lasthour:
                daycounter += 1
            hours_added.append(int(hour)+ daycounter * 24)
            lasthour = int(hour)
        
        #temp parser
        temp = re.findall(r'Temp            ...............................................................', location_texts[1+index])
        forec = temp[0].replace('Temp            ','')
        temps = [forec[i:i+3] for i in range(0, len(forec), 3)]
        
        #dew point parser
        dew = re.findall(r'Dewpt           ...............................................................', location_texts[1+index])
        dewp = dew[0].replace('Dewpt           ','')
        dewpoint = [dewp[i:i+3] for i in range(0, len(dewp), 3)]
        
        #wind direction parser
        wind = re.findall(r'Wind dir        ...............................................................', location_texts[1+index])
        windDi = wind[0].replace('Wind dir        ','')
        windDirection= [windDi[i:i+3] for i in range(0, len(windDi), 3)]

        #windspeed parser
        winds = re.findall(r'Wind spd        ...............................................................',location_texts[1+index])
        windsp = winds[0].replace('Wind spd        ','')
        windSpeed = [windsp[i:i+3] for i in range(0, len(windsp), 3)]

        #clouds parser
        cl= re.findall(r'Clouds           .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. .. ..', location_texts[1+index])
        clo = cl[0].replace('Clouds           ','')
        clouds = [clo[i:i+3] for i in range(0, len(clo), 3)]
        
        #Relative humidity parser
        rh1 = re.findall(r'RH              ...............................................................', location_texts[1+index])
        rh2 = rh1[0].replace('RH              ','')
        rh = [rh2[i:i+3] for i in range(0, len(rh2), 3)]
    
        
        #Probability of Precipitation: The next three items are not part of the 3 hour time series
        prec = re.findall(r'PoP 12hr                    ...................................................', location_texts[1+index])
        precip = prec[0].replace('PoP 12hr                     ','')
        precipit = precip.replace('          ',',')
        pop = precipit.split(',')
        time_series_dict['pop12hours'] = pop
        
        #Quantitative Precipitation Forecast
        quantit= re.findall(r'QPF 12hr                 ......      ......      ......      ......      ......',location_texts[1+index])
        quantiprec = quantit[0].replace('QPF 12hr                 ','')
        quantiprecip = quantiprec.replace('       ',',')
        qpf = quantiprecip.split(',')
        time_series_dict['QPF12h'] = qpf
        
        #Not all of the stations measure the probability of snow e.g. Phoenix, Houston. If your PFM doesn't contain this part of
        #the forecast you can just add # to the code
        s = re.findall(r'Snow 12hr                .......     .......     .......                       ',location_texts[1+index])
        snow = s[0].replace('Snow 12hr                 ','')
        snow1 = snow.replace('                        ','')
        snow12 = snow1.replace('       ',',')
        snow12h = snow12.split(',')
        time_series_dict['Snow12H'] = snow12h
        
        #align hour and temps
        
        ts = []
        
        for index2 in range(len(temps)):
            
            
            #Hours_added should always append to index2+1 unless the amount of hours and observations is the same. 
            ts.append([hours_added[index2+1],temps[index2],dewpoint[index2], rh[index2], windDirection[index2], windSpeed[index2], clouds[index2]])
        time_series_dict['timeseries'] = ts
        three_hr_timeseries_json.append(time_series_dict)
        
    return three_hr_timeseries_json

        
        
fresh_json = returnthree_hr_timeseries_json_from_pfm(PFM)
print(fresh_json[0:20])
# Out:
# ['31.18N  90.47W E', '30.53N  91.15W E', '30.25N  89.77W E', '30.00N  90.25W E', '30.07N  89.93W E', '30.42N  89.08W E', '30.47N  88.53W E']
# [{'location': '31.18N  90.47W E', 'start_date': 'Tue 07/19/22 ', 'pop12hours': ['20', ' 5', '10', ' 5', '40'], 'QPF12h': ['     0', '    0', '    0', '    0', '    0'], 'Snow12H': ['00-00', '00-00', '00-00'], 'timeseries': [[7, ' 75', ' 73', ' 94', ' SW', '  4', 'FW '], [10, ' 82', ' 74', ' 77', ' SW', ' 12', 'SC '], [13, ' 88', ' 73', ' 61', ' SW', ' 11', 'SC '], [16, ' 94', ' 72', ' 49', ' SW', ' 11', 'SC '], [19, ' 86', ' 73', ' 65', '  S', ' 12', 'SC '], [22, ' 80', ' 73', ' 79', '  S', '  8', 'SC '], [25, ' 78', ' 73', ' 85', ' SW', '  6', 'FW '], [28, ' 76', ' 73', ' 90', ' SW', '  6', 'SC '], [31, ' 76', ' 73', ' 90', ' SW', '  4', 'SC '], [34, ' 84', ' 75', ' 74', ' SW', ' 12', 'SC '], [37, ' 90', ' 74', ' 60', ' SW', ' 12', 'SC '], [40, ' 96', ' 71', ' 45', ' SW', ' 12', 'SC '], [43, ' 89', ' 72', ' 57', ' SW', ' 10', 'SC '], [46, ' 81', ' 74', ' 79', ' SW', '  6', 'FW '], [49, ' 78', ' 74', ' 88', ' SW', '  6', 'FW '], [52, ' 77', ' 73', ' 87', ' SW', '  6', 'SC '], [55, ' 77', ' 74', ' 90', ' SW', '  5', 'SC '], [58, ' 84', ' 75', ' 74', '  W', ' 10', 'SC '], [61, ' 89', ' 74', ' 61', ' SW', '  8', 'B1 '], [64, ' 94', ' 73', ' 51', ' SW', '  9', 'B1 '], [67, ' 85', ' 74', ' 70', ' SW', '  9', 'B1']]}, {'location': '30.53N  91.15W E', 'start_date': 'Tue 07/19/22 ', 'pop12hours': ['20', ' 0', '20', ' 5', '50'], 'QPF12h': ['     0', '    0', '    0', '    0', ' 0.01'], 'Snow12H': ['00-00', '00-00', '00-00'], 'timeseries': [[7, ' 78', ' 75', ' 91', ' SW', '  4', 'FW '], [10, ' 85', ' 76', ' 75', ' SW', ' 11', 'SC '], [13, ' 90', ' 75', ' 62', ' SW', ' 11', 'SC '], [16, ' 95', ' 75', ' 53', ' SW', ' 14', 'B1 '], [19, ' 88', ' 74', ' 63', ' SW', ' 13', 'SC '], [22, ' 82', ' 75', ' 79', ' SW', ' 12', 'SC '], [25, ' 79', ' 75', ' 88', ' SW', '  9', 'SC '], [28, ' 78', ' 75', ' 91', ' SW', '  8', 'SC '], [31, ' 79', ' 76', ' 91', ' SW', '  5', 'FW '], [34, ' 87', ' 77', ' 72', ' SW', ' 11', 'SC '], [37, ' 92', ' 75', ' 58', ' SW', ' 11', 'SC '], [40, ' 97', ' 74', ' 48', ' SW', ' 16', 'SC '], [43, ' 90', ' 75', ' 62', ' SW', ' 12', 'FW '], [46, ' 83', ' 76', ' 80', ' SW', ' 12', 'FW '], [49, ' 81', ' 76', ' 85', ' SW', '  9', 'FW '], [52, ' 79', ' 76', ' 91', ' SW', '  6', 'SC '], [55, ' 79', ' 77', ' 94', ' SW', '  4', 'SC '], [58, ' 86', ' 77', ' 75', '  W', ' 10', 'SC '], [61, ' 91', ' 75', ' 60', ' SW', '  9', 'B1 '], [64, ' 96', ' 74', ' 49', ' SW', ' 11', 'B1 '], [67, ' 87', ' 75', ' 68', ' SW', '  9', 'B1']]}, {'location': '30.25N  89.77W E', 'start_date': 'Tue 07/19/22 ', 'pop12hours': ['30', ' 5', '30', ' 5', '50'], 'QPF12h': ['     0', '    0', '    0', '    0', ' 0.01'], 'Snow12H': ['00-00', '00-00', '00-00'], 'timeseries': [[7, ' 79', ' 74', ' 85', ' SW', '  3', 'SC '], [10, ' 86', ' 75', ' 70', ' SW', '  9', 'SC '], [13, ' 90', ' 74', ' 60', ' SW', '  9', 'SC '], [16, ' 94', ' 74', ' 53', ' SW', ' 13', 'SC '], [19, ' 88', ' 75', ' 66', ' SW', ' 10', 'SC '], [22, ' 83', ' 75', ' 77', ' SW', '  6', 'SC '], [25, ' 81', ' 74', ' 79', ' SW', '  6', 'SC '], [28, ' 79', ' 74', ' 85', ' SW', '  6', 'SC '], [31, ' 79', ' 74', ' 85', ' SW', '  4', 'SC '], [34, ' 88', ' 75', ' 66', ' SW', '  9', 'FW '], [37, ' 92', ' 74', ' 56', ' SW', ' 11', 'SC '], [40, ' 96', ' 74', ' 49', ' SW', ' 13', 'SC '], [43, ' 89', ' 75', ' 64', ' SW', ' 10', 'SC '], [46, ' 83', ' 76', ' 80', ' SW', '  6', 'FW '], [49, ' 81', ' 75', ' 82', ' SW', '  6', 'SC '], [52, ' 79', ' 74', ' 85', ' SW', '  5', 'SC '], [55, ' 79', ' 75', ' 88', ' SW', '  4', 'SC '], [58, ' 85', ' 75', ' 72', '  W', '  8', 'SC '], [61, ' 90', ' 75', ' 62', ' SW', '  9', 'B1 '], [64, ' 95', ' 75', ' 53', ' SW', ' 11', 'B1 '], [67, ' 88', ' 75', ' 66', ' SW', '  8', 'SC']]}, {'location': '30.00N  90.25W E', 'start_date': 'Tue 07/19/22 ', 'pop12hours': ['30', ' 5', '30', ' 5', '50'], 'QPF12h': ['  0.04', '    0', '    0', '    0', ' 0.04'], 'Snow12H': ['00-00', '00-00', '00-00'], 'timeseries': [[7, ' 80', ' 77', ' 91', ' SW', '  5', 'SC '], [10, ' 86', ' 76', ' 72', ' SW', ' 1 ...

# %%
fresh_json
# Out:
# [{'location': '31.18N  90.47W E',
#   'start_date': 'Tue 07/19/22 ',
#   'pop12hours': ['20', ' 5', '10', ' 5', '40'],
#   'QPF12h': ['     0', '    0', '    0', '    0', '    0'],
#   'Snow12H': ['00-00', '00-00', '00-00'],
#   'timeseries': [[7, ' 75', ' 73', ' 94', ' SW', '  4', 'FW '],
#    [10, ' 82', ' 74', ' 77', ' SW', ' 12', 'SC '],
#    [13, ' 88', ' 73', ' 61', ' SW', ' 11', 'SC '],
#    [16, ' 94', ' 72', ' 49', ' SW', ' 11', 'SC '],
#    [19, ' 86', ' 73', ' 65', '  S', ' 12', 'SC '],
#    [22, ' 80', ' 73', ' 79', '  S', '  8', 'SC '],
#    [25, ' 78', ' 73', ' 85', ' SW', '  6', 'FW '],
#    [28, ' 76', ' 73', ' 90', ' SW', '  6', 'SC '],
#    [31, ' 76', ' 73', ' 90', ' SW', '  4', 'SC '],
#    [34, ' 84', ' 75', ' 74', ' SW', ' 12', 'SC '],
#    [37, ' 90', ' 74', ' 60', ' SW', ' 12', 'SC '],
#    [40, ' 96', ' 71', ' 45', ' SW', ' 12', 'SC '],
#    [43, ' 89', ' 72', ' 57', ' SW', ' 10', 'SC '],
#    [46, ' 81', ' 74', ' 79', ' SW', '  6', 'FW '],
#    [49, ' 78', ' 74', ' 88', ' SW', '  6', 'FW '],
#    [52, ' 77', ' 73', ' 87', ' SW', '  6', 'SC '],
#    [55, ' 77', ' 74', ' 90', ' SW', '  5', 'SC '],
#    [58, ' 84', ' 75', ' 74', '  W', ' 10', 'SC '],
#    [61, ' 89', ' 74', ' 61', ' SW', '  8', 'B1 '],
#    [64, ' 94', ' 73', ' 51', ' SW', '  9', 'B1 '],
#    [67, ' 85', ' 74', ' 70', ' SW', '  9', 'B1']]},
#  {'location': '30.53N  91.15W E',
#   'start_date': 'Tue 07/19/22 ',
#   'pop12hours': ['20', ' 0', '20', ' 5', '50'],
#   'QPF12h': ['     0', '    0', '    0', '    0', ' 0.01'],
#   'Snow12H': ['00-00', '00-00', '00-00'],
#   'timeseries': [[7, ' 78', ' 75', ' 91', ' SW', '  4', 'FW '],
#    [10, ' 85', ' 76', ' 75', ' SW', ' 11', 'SC '],
#    [13, ' 90', ' 75', ' 62', ' SW', ' 11', 'SC '],
#    [16, ' 95', ' 75', ' 53', ' SW', ' 14', 'B1 '],
#    [19, ' 88', ' 74', ' 63', ' SW', ' 13', 'SC '],
#    [22, ' 82', ' 75', ' 79', ' SW', ' 12', 'SC '],
#    [25, ' 79', ' 75', ' 88', ' SW', '  9', 'SC '],
#    [28, ' 78', ' 75', ' 91', ' SW', '  8', 'SC '],
#    [31, ' 79', ' 76', ' 91', ' SW', '  5', 'FW '],
#    [34, ' 87', ' 77', ' 72', ' SW', ' 11', 'SC '],
#    [37, ' 92', ' 75', ' 58', ' SW', ' 11', 'SC '],
#    [40, ' 97', ' 74', ' 48', ' SW', ' 16', 'SC '],
#    [43, ' 90', ' 75', ' 62', ' SW', ' 12', 'FW '],
#    [46, ' 83', ' 76', ' 80', ' SW', ' 12', 'FW '],
#    [49, ' 81', ' 76', ' 85', ' SW', '  9', 'FW '],
#    [52, ' 79', ' 76', ' 91', ' SW', '  6', 'SC '],
#    [55, ' 79', ' 77', ' 94', ' SW', '  4', 'SC '],
#    [58, ' 86', ' 77', ' 75', '  W', ' 10', 'SC '],
#    [61, ' 91', ' 75', ' 60', ' SW', '  9', 'B1 '],
#    [64, ' 96', ' 74', ' 49', ' SW', ' 11', 'B1 '],
#    [67, ' 87', ' 75', ' 68', ' SW', '  9', 'B1']]},
#  {'location': '30.25N  89.77W E',
#   'start_date': 'Tue 07/19/22 ',
#   'pop12hours': ['30', ' 5', '30', ' 5', '50'],
#   'QPF12h': ['     0', '    0', '    0', '    0', ' 0.01'],
#   'Snow12H': ['00-00', '00-00', '00-00'],
#   'timeseries': [[7, ' 79', ' 74', ' 85', ' SW', '  3', 'SC '],
#    [10, ' 86', ' 75', ' 70', ' SW', '  9', 'SC '],
#    [13, ' 90', ' 74', ' 60', ' SW', '  9', 'SC '],
#    [16, ' 94', ' 74', ' 53', ' SW', ' 13', 'SC '],
#    [19, ' 88', ' 75', ' 66', ' SW', ' 10', 'SC '],
#    [22, ' 83', ' 75', ' 77', ' SW', '  6', 'SC '],
#    [25, ' 81', ' 74', ' 79', ' SW', '  6', 'SC '],
#    [28, ' 79', ' 74', ' 85', ' SW', '  6', 'SC '],
#    [31, ' 79', ' 74', ' 85', ' SW', '  4', 'SC '],
#    [34, ' 88', ' 75', ' 66', ' SW', '  9', 'FW '],
#    [37, ' 92', ' 74', ' 56', ' SW', ' 11', 'SC '],
#    [40, ' 96', ' 74', ' 49', ' SW', ' 13', 'SC '],
#    [43, ' 89', ' 75', ' 64', ' SW', ' 10', 'SC '],
#    [46, ' 83', ' 76', ' 80', ' SW', '  6', 'FW '],
#    [49, ' 81', ' 75', ' 82', ' SW', '  6', 'SC '],
#    [52, ' 79', ' 74', ' 85', ' SW', '  5', 'SC '],
#    [55, ' 79', ' 75', ' 88', ' SW', '  4', 'SC '],
#    [58, ' 85', ' 75', ' 72', '  W', '  8', 'SC '],
#    [61, ' 90', ' 75', ' 62', ' SW', '  9', 'B1 '],
#    [64, ' 95', ' 75', ' 53', ' SW', ' 11', 'B1 '],
#    [67, ' 88', ' 75', ' 66', ' SW', '  8', 'SC']]},
#  {'location': '30.00N  90.25W E',
#   'start_date': 'Tue 07/19/22 ',
#   'pop12hours': ['30', ' 5', '30', ' 5', '50'],
#   'QPF12h': ['  0.04', '    0', '    0', '    0', ' 0.04'],
#   'Snow12H': ['00-00', '00-00', '00-00'],
#   'timeseries': [[7, ' 80', ' 77', ' 91', ' SW', '  5', 'SC '],
#    [10, ' 86', ' 76', ' 72', ' SW', ' 10', 'SC '],
#    [13, ' 90', ' 75', ' 62', ' SW', ' 12', 'SC '],
#    [16, ' 93', ' 75', ' 56', ' SW', ' 13', 'B1 '],
#    [19, ' 88', ' 76', ' 68', ' SW', ' 12', 'SC '],
#    [22, ' 83', ' 76', ' 80', ' SW', '  9', 'SC '],
#    [25, ' 81', ' 76', ' 85', ' SW', '  9', 'FW '],
#    [28, ' 80', ' 77', ' 91', ' SW', '  6', 'SC '],
#    [31, ' 81', ' 77', ' 88', ' SW', '  6', 'SC '],
#    [34, ' 88', ' 77', ' 70', ' SW', ' 11', 'SC '],
#    [37, ' 92', ' 75', ' 58', ' SW', ' 12', 'SC '],
#    [40, ' 95', ' 75', ' 53', ' SW', ' 14', 'SC '],
#    [43, ' 88', ' 75', ' 66', ' SW', ' 13', 'SC '],
#    [46, ' 83', ' 76', ' 80', ' SW', ' 10', 'SC '],
#    [49, ' 82', ' 77', ' 85', ' SW', '  9', 'SC '],
#    [52, ' 81', ' 77', ' 88', ' SW', '  6', 'SC '],
#    [55, ' 81', ' 77', ' 88', ' SW', '  5', 'SC '],
#    [58, ' 86', ' 77', ' 75', '  W', '  9', 'SC '],
#    [61, ' 90', ' 76', ' 64', ' SW', ' 10', 'B2 '],
#    [64, ' 94', ' 76', ' 56', ' SW', ' 11', 'B2 '],
#    [67, ' 87', ' 76', ' 70', ' SW', ' 10', 'B1']]},
#  {'location': '30.07N  89.93W E',
#   'start_date': 'Tue 07/19/22 ',
#   'pop12hours': ['30', ' 5', '20', ' 5', '50'],
#   'QPF12h': ['  0.17', ' 0.05', ' 0.02', '    0', ' 0.01'],
#   'Snow12H': ['00-00', '00-00', '00-00'],
#   'timeseries': [[7, ' 80', ' 76', ' 88', ' SW', '  8', 'SC '],
#    [10, ' 86', ' 77', ' 75', ' SW', '  9', 'SC '],
#    [13, ' 88', ' 76', ' 68', '  W', ' 10', 'SC '],
#    [16, ' 91', ' 77', ' 64', '  S', ' 12', 'B1 '],
#    [19, ' 87', ' 77', ' 72', ' SW', ' 12', 'B1 '],
#    [22, ' 83', ' 77', ' 82', ' SW', ' 10', 'FW '],
#    [25, ' 81', ' 76', ' 85', ' SW', '  9', 'SC '],
#    [28, ' 80', ' 76', ' 88', ' SW', '  8', 'SC '],
#    [31, ' 81', ' 77', ' 88', ' SW', '  9', 'SC '],
#    [34, ' 87', ' 77', ' 72', ' SW', ' 10', 'FW '],
#    [37, ' 89', ' 76', ' 66', ' SW', ' 11', 'SC '],
#    [40, ' 92', ' 77', ' 62', ' SW', ' 13', 'SC '],
#    [43, ' 87', ' 77', ' 72', ' SW', ' 11', 'SC '],
#    [46, ' 83', ' 77', ' 82', ' SW', ' 11', 'SC '],
#    [49, ' 82', ' 77', ' 85', ' SW', ' 10', 'SC '],
#    [52, ' 81', ' 77', ' 88', ' SW', '  8', 'SC '],
#    [55, ' 81', ' 77', ' 88', ' SW', '  8', 'SC '],
#    [58, ' 85', ' 78', ' 80', '  W', '  9', 'SC '],
#    [61, ' 88', ' 76', ' 68', ' SW', '  9', 'B1 '],
#    [64, ' 91', ' 77', ' 64', ' SW', ' 11', 'B1 '],
#    [67, ' 87', ' 77', ' 72', ' SW', ' 10', 'B1']]},
#  {'location': '30.42N  89.08W E',
#   'start_date': 'Tue 07/19/22 ',
#   'pop12hours': ['30', '10', '30', '10', '50'],
#   'QPF12h': ['     0', '    0', ' 0.01', '    0', '    0'],
#   'Snow12H': ['00-00', '00-00', '00-00'],
#   'timeseries': [[7, ' 79', ' 76', ' 91', '  W', '  5', 'SC '],
#    [10, ' 85', ' 76', ' 75', ' SW', ' 10', 'SC '],
#    [13, ' 87', ' 76', ' 70', ' SW', ' 12', 'SC '],
#    [16, ' 90', ' 76', ' 64', '  S', ' 13', 'SC '],
#    [19, ' 86', ' 76', ' 72', '  S', ' 12', 'B1 '],
#    [22, ' 84', ' 77', ' 80', ' SW', ' 11', 'SC '],
#    [25, ' 81', ' 76', ' 85', ' SW', ' 10', 'SC '],
#    [28, ' 80', ' 76', ' 88', ' SW', '  8', 'SC '],
#    [31, ' 80', ' 77', ' 91', '  W', '  6', 'SC '],
#    [34, ' 87', ' 77', ' 72', ' SW', ' 12', 'SC '],
#    [37, ' 89', ' 76', ' 66', ' SW', ' 12', 'SC '],
#    [40, ' 91', ' 76', ' 62', '  S', ' 13', 'SC '],
#    [43, ' 87', ' 77', ' 72', ' SW', ' 12', 'SC '],
#    [46, ' 84', ' 77', ' 80', ' SW', ' 11', 'SC '],
#    [49, ' 82', ' 77', ' 85', ' SW', ' 10', 'SC '],
#    [52, ' 80', ' 76', ' 88', ' SW', '  8', 'SC '],
#    [55, ' 80', ' 77', ' 91', ' SW', '  6', 'SC '],
#    [58, ' 85', ' 77', ' 77', ' SW', ' 10', 'SC '],
#    [61, ' 89', ' 76', ' 66', ' SW', ' 10', 'B1 '],
#    [64, ' 92', ' 76', ' 60', '  S', ' 12', 'B1 '],
#    [67, ' 88', ' 77', ' 70', ' SW', '  9', 'B1']]},
#  {'location': '30.47N  88.53W E',
#   'start_date': 'Tue 07/19/22 ',
#   'pop12hours': ['30', '20', '30', '10', '50'],
#   'QPF12h': ['  0.02', '    0', ' 0.02', '    0', ' 0.01'],
#   'Snow12H': ['00-00', '00-00', '00-00'],
#   'timeseries': [[7, ' 79', ' 77', ' 94', '  W', '  4', 'SC '],
#    [10, ' 84', ' 78', ' 82', ' SW', '  8', 'SC '],
#    [13, ' 87', ' 77', ' 72', ' SW', ' 11', 'SC '],
#    [16, ' 91', ' 78', ' 66', ' SW', ' 13', 'B1 '],
#    [19, ' 85', ' 77', ' 77', ' SW', ' 11', 'SC '],
#    [22, ' 81', ' 77', ' 88', ' SW', '  9', 'SC '],
#    [25, ' 81', ' 76', ' 85', ' SW', '  8', 'SC '],
#    [28, ' 79', ' 76', ' 91', '  W', '  8', 'SC '],
#    [31, ' 79', ' 77', ' 94', '  W', '  5', 'SC '],
#    [34, ' 87', ' 78', ' 75', '  W', ' 11', 'SC '],
#    [37, ' 89', ' 78', ' 70', ' SW', ' 13', 'B1 '],
#    [40, ' 91', ' 78', ' 66', ' SW', ' 13', 'B1 '],
#    [43, ' 86', ' 77', ' 75', ' SW', ' 11', 'SC '],
#    [46, ' 82', ' 78', ' 88', ' SW', ' 10', 'SC '],
#    [49, ' 81', ' 77', ' 88', ' SW', ' 10', 'SC '],
#    [52, ' 79', ' 76', ' 91', ' SW', '  8', 'SC '],
#    [55, ' 80', ' 77', ' 91', '  W', '  6', 'B1 '],
#    [58, ' 84', ' 78', ' 82', '  W', '  8', 'B1 '],
#    [61, ' 88', ' 77', ' 70', ' SW', ' 10', 'B1 '],
#    [64, ' 92', ' 78', ' 64', ' SW', ' 12', 'B1 '],
#    [67, ' 86', ' 77', ' 75', ' SW', ' 10', 'B1']]}]
